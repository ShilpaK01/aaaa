# %% [markdown]
# # Introduction
#
# In this supply chain analytics analysis, we encountered the challenge of working with a dataset consisting of 100 rows and 24 columns. During the Exploratory Data Analysis phase, we conducted quality control checks, assessed supply chain risks, performed Inventory Optimization Analysis using the Economic Order Quantity (EOQ) method, conducted customer segmentation analysis, and explored lead times optimization. However, in the modeling phase, we found that using LightGBM and RNN models was not suitable for this small dataset, resulting in unsatisfactory outcomes. Therefore, we recommend utilizing a larger dataset or considering alternatives such as linear regression, decision trees, or random forests to achieve better results in cost optimization and demand forecasting.In this supply chain analytics analysis, we encountered the challenge of working with a dataset consisting of 100 rows and 24 columns. During the Exploratory Data Analysis phase, we conducted quality control checks, assessed supply chain risks, performed Inventory Optimization Analysis using the Economic Order Quantity (EOQ) method, conducted customer segmentation analysis, and explored lead times optimization. However, in the modeling phase, we found that using LightGBM and RNN models was not suitable for this small dataset, resulting in unsatisfactory outcomes. Therefore, we recommend utilizing a larger dataset or considering alternatives such as linear regression, decision trees, or random forests to achieve better results in cost optimization and demand forecasting.

# %% [markdown]
# # Load data

# %%
# Disable warning

import warnings

warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=FutureWarning)

# %%
import pandas as pd

supply_data = pd.read_csv("/kaggle/input/supply-chain-analysis/supply_chain_data.csv")

# %%
supply_data.head()
# Out:
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.808006            55                      802
# 1     skincare  SKU1  14.843523            95                      736
# 2     haircare  SKU2  11.319683            34                        8
# 3     skincare  SKU3  61.163343            68                       83
# 4     skincare  SKU4   4.805496            26                      871
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58           7
# 1        7460.900065                Female            53          30
# 2        9577.749626               Unknown             1          10
# 3        7766.836426            Non-binary            23          13
# 4        2686.505152            Non-binary             5           3
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# 0                96  ...    Mumbai        29                 215
# 1                37  ...    Mumbai        23                 517
# 2                88  ...    Mumbai        12                 971
# 3                59  ...   Kolkata        24                 937
# 4                56  ...     Delhi         5                 414
#
#   Manufacturing lead time Manufacturing costs  Inspection results  \
# 0                      29           46.279879             Pending
# 1                      30           33.616769             Pending
# 2                      27           30.688019             Pending
# 3                      18           35.624741                Fail
# 4                       3           92.065161                Fail
#
#    Defect rates  Transportation modes   Routes       Costs
# 0      0.226410                  Road  Route B  187.752075
# 1      4.854068                  Road  Route B  503.065579
# 2      4.580593                   Air  Route C  141.920282
# 3      4.746649                  Rail  Route A  254.776159
# 4      3.145580                   Air  Route A  923.440632
#
# [5 rows x 24 columns]

# %%
supply_data.shape
# Out:
# (100, 24)

# %%
supply_data.columns
# Out:
# Index(['Product type', 'SKU', 'Price', 'Availability',
#        'Number of products sold', 'Revenue generated', 'Customer demographics',
#        'Stock levels', 'Lead times', 'Order quantities', 'Shipping times',
#        'Shipping carriers', 'Shipping costs', 'Supplier name', 'Location',
#        'Lead time', 'Production volumes', 'Manufacturing lead time',
#        'Manufacturing costs', 'Inspection results', 'Defect rates',
#        'Transportation modes', 'Routes', 'Costs'],
#       dtype='object')

# %% [markdown]
# **Feature explanation**
#
# - **Product Type**: The type of product associated with specific data in the supply chain.
# - **SKU (Stock Keeping Unit)**: Unique code used to identify a particular product.
# - **Price**: The price of the product or item in the supply chain.
# - **Availability**: Information about product availability.
# - **Number of Products Sold**: The number of products that have been sold in a certain time period.
# - **Revenue Generated**: Total revenue generated from product sales in a certain time period.
# - **Customer demographics**: Information about customer characteristics, such as age, gender, geographic location, etc.
# - **Stock Levels**: The number of products still available in stock at any given time.
# - **Lead Times**: The time required to order or receive products from suppliers.
# - **Order Quantities**: The number of products ordered in one order or shipment.
# - **Shipping Times**: The time required to ship products from the warehouse or distribution center to customers.
# - **Shipping Carriers**: Companies or services used to ship products to customers.
# - **Shipping Costs**: Costs associated with shipping products, including delivery fees and additional fees.
# - **Supplier Name**: Name of supplier or vendor who provides products or materials to the company.
# - **Location**: The physical location associated with the data in the supply chain, such as the location of a warehouse or distribution center.
# - **Lead Time**: The time required to obtain products or materials from a particular supplier.
# - **Production Volumes**: The number of products produced in a certain time period.
# - **Manufacturing Lead Time**: The time required to produce a product, from ordering materials until the product is ready.
# - **Manufacturing Costs**: Costs related to the production process, including raw material costs, labor, etc.
# - **Inspection Results**: Results of product or material quality inspection.
# - **Defect Rates**: The level of defects or defects in the products produced.
# - **Transportation Modes**: The transportation mode used to send products, such as land, sea or air.
# - **Routes**: Routes or paths used to send products from one point to another in the supply chain.
# - **Costs**: Costs related to various aspects of the supply chain, including transportation costs, production costs, and other costs.

# %%
supply_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Product type             100 non-null    object
#  1   SKU                      100 non-null    object
#  2   Price                    100 non-null    float64
#  3   Availability             100 non-null    int64
#  4   Number of products sold  100 non-null    int64
#  5   Revenue generated        100 non-null    float64
#  6   Customer demographics    100 non-null    object
#  7   Stock levels             100 non-null    int64
#  8   Lead times               100 non-null    int64
#  9   Order quantities         100 non-null    int64
#  10  Shipping times           100 non-null    int64
#  11  Shipping carriers        100 non-null    object
#  12  Shipping costs           100 non-null    float64
#  13  Supplier name            100 non-null    object
#  14  Location                 100 non-null    object
#  15  Lead time                100 non-null    int64
#  16  Production volumes       100 non-null    int64
#  17  Manufacturing lead time  100 non-null    int64
#  18  Manufacturing costs      100 non-null    float64
#  19  Inspection results       100 non-null    object
#  20  Defect rates             100 non-null    float64
#  21  Transportation modes     100 non-null    object
#  22  Routes                   100 non-null    object
#  23  Costs                    100 non-null    float64
# dtypes: float64(6), int64(9), object(9)
# memory usage: 18.9+ KB

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# ### Checking for missing values

# %%
# Check for missing values
missing_values = supply_data.isnull().sum()

# Display columns with missing values and the count of missing values
missing_values = missing_values[missing_values > 0]

if not missing_values.empty:
    print("Columns with missing values:")
    for column, count in missing_values.items():
        print(f"{column}: {count} missing values")
else:
    print("There are no columns with missing value")
# Out:
# There are no columns with missing value

# %% [markdown]
# ### Check for duplicate data

# %%
if supply_data.duplicated().any():
    print(f"There are as many as {supply_data.duplicated().sum()} duplicate data.")
else:
    print("There are no duplicate data.")
# Out:
# There are no duplicate data.

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Quality control check

# %%
import plotly.express as px

defect_rates_by_product = supply_data.groupby("Product type")['Defect rates'].mean().reset_index()

# Create a bar chart using Plotly
fig = px.bar(defect_rates_by_product, x='Product type', y='Defect rates', title='Defect Rates by Product Type')

# Customize the color scale for bars
color_scale = px.colors.qualitative.Set3  # You can choose a different color scale
fig.update_traces(marker_color=color_scale)

# Customize the appearance of the chart
fig.update_layout(
    xaxis_title="Product Type",
    yaxis_title="Mean Defect Rates",
    xaxis=dict(categoryorder='total descending'),
    yaxis=dict(title='Mean Defect Rates'),
    plot_bgcolor='white',
    title_x=0.5,
    showlegend=True  # Hide the legend
)

# Show the plot
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="09791ca2-7ee0-4356-a552-84986d3fff3a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("09791ca2-7ee0-4356-a552-84986d3fff3a")) {                    Plotly.newPlot(                        "09791ca2-7ee0-4356-a552-84986d3fff3a",                        [{"alignmentgroup":"True","hovertemplate":"Product type=%{x}\u003cbr\u003eDefect rates=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":["rgb(141,211,199)","rgb(255,255,179)","rgb(190,186,218)","rgb(251,128,114)","rgb(128,177,211)","rgb(253,180,98)","rgb(179,222,105)","rgb(252,205,229)","rgb(217,217,217)","rgb(188,128,189)","rgb(204,235,197)","rgb(255,237,111)"],"pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["cosmetics","haircare","skincare"],"xaxis":"x","y":[1.9192869782813182,2.4831501929246245,2.334680781980237],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5 ...

# %% [markdown]
# ### Supply chain risk assessment

# %%
risk_data = supply_data[['SKU', 'Lead times', 'Stock levels']]
risk_data.head()
# Out:
#     SKU  Lead times  Stock levels
# 0  SKU0           7            58
# 1  SKU1          30            53
# 2  SKU2          10             1
# 3  SKU3          13            23
# 4  SKU4           3             5

# %%
risk_data['Risk score'] = risk_data['Lead times'] * (1-risk_data.loc[:,'Stock levels'])

# %%
# Sort the risk_data by 'Risk score' in descending order and select top 10 highest-risk data
risk_data = risk_data.sort_values(by='Risk score', ascending=False)[:10]

# Create a bar plot using Plotly Express
fig = px.bar(risk_data, x='SKU', y='Risk score', title='Top 10 Highest-Risk Data',
             labels={'Risk score': 'Risk Score', 'SKU': 'SKU'},
             text='Risk score')

# Customize the appearance of the plot
fig.update_traces(texttemplate='%{text:.2f}', textposition='outside')
fig.update_layout(xaxis_title='SKU', yaxis_title='Risk Score', title_x=0.5)

# Show the plot
fig.show()
# Out:
# <div>                            <div id="6790f532-62ed-458c-9137-772c0e4f8160" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6790f532-62ed-458c-9137-772c0e4f8160")) {                    Plotly.newPlot(                        "6790f532-62ed-458c-9137-772c0e4f8160",                        [{"alignmentgroup":"True","hovertemplate":"SKU=%{x}\u003cbr\u003eRisk Score=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[8.0,0.0,0.0,-5.0,-12.0,-16.0,-28.0,-37.0,-40.0,-45.0],"textposition":"outside","x":["SKU68","SKU2","SKU34","SKU16","SKU4","SKU78","SKU87","SKU76","SKU8","SKU47"],"xaxis":"x","y":[8,0,0,-5,-12,-16,-28,-37,-40,-45],"yaxis":"y","type":"bar","texttemplate":"%{text:.2f}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay ...

# %% [markdown]
# ### Inventory Optimization Analysis with EOQ

# %%
# we assume for holding cost 0.2
holdingcost = 0.2

# %%
import numpy as np

def calculate_eoq(data):
    S = data['Costs']
    D = data['Number of products sold'] 
    H = data['Number of products sold'] * holdingcost
    EOQ = np.sqrt((2*S*D)/H)
    return round(EOQ)

# %%
supply_data['EOQ'] = calculate_eoq(supply_data)

# %%
comparison_columns = supply_data[['SKU', 'EOQ','Order quantities']]
comparison_columns.head()
# Out:
#     SKU   EOQ  Order quantities
# 0  SKU0  43.0                96
# 1  SKU1  71.0                37
# 2  SKU2  38.0                88
# 3  SKU3  50.0                59
# 4  SKU4  96.0                56

# %%
# Extracting the top 10 rows for comparison
top_10_comparison = comparison_columns.head(10)

# Creating a bar plot to compare EOQ and Order Quantities for the top 10 SKUs
fig = px.bar(top_10_comparison, x='SKU', y=['EOQ', 'Order quantities'], 
             title='Comparison of EOQ and Order Quantities for Top 10 SKUs')

fig.update_layout(
    title_x=0.5
)

# Displaying the plot
fig.show()
# Out:
# <div>                            <div id="1d800e56-3fa2-406b-9f01-2cdbd3445bfb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1d800e56-3fa2-406b-9f01-2cdbd3445bfb")) {                    Plotly.newPlot(                        "1d800e56-3fa2-406b-9f01-2cdbd3445bfb",                        [{"alignmentgroup":"True","hovertemplate":"variable=EOQ\u003cbr\u003eSKU=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"EOQ","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"EOQ","offsetgroup":"EOQ","orientation":"v","showlegend":true,"textposition":"auto","x":["SKU0","SKU1","SKU2","SKU3","SKU4","SKU5","SKU6","SKU7","SKU8","SKU9"],"xaxis":"x","y":[43.0,71.0,38.0,50.0,96.0,49.0,37.0,90.0,71.0,100.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"variable=Order quantities\u003cbr\u003eSKU=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Order quantities","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Order quantities","offsetgroup":"Order quantities","orientation":"v","showlegend":true,"textposition":"auto","x":["SKU0","SKU1","SKU2","SKU3","SKU4","SKU5","SKU6","SKU7","SKU8","SKU9"],"xaxis":"x","y":[96.0,37.0,88.0,59.0,56.0,66.0,58.0,11.0,15.0,83.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mes ...

# %% [markdown]
# ### Customer segmentation analysis

# %%
revenue_avg_by_demo_prod = supply_data.groupby(['Customer demographics', 'Product type'])['Revenue generated'].mean().reset_index()
revenue_sum_by_demo_prod = supply_data.groupby(['Customer demographics', 'Product type'])['Revenue generated'].sum().reset_index()

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# Create a palette of different colors for each product type
colors = px.colors.qualitative.Set3

# Create a subplot with 1 row and 2 columns
fig = make_subplots(rows=1, cols=2, subplot_titles=('Average Revenue', 'Total Revenue'))

# Plot for average revenue
for i, product_type in enumerate(revenue_avg_by_demo_prod['Product type'].unique()):
    subset = revenue_avg_by_demo_prod[revenue_avg_by_demo_prod['Product type'] == product_type]
    fig.add_trace(
        go.Bar(
            x=subset['Customer demographics'],
            y=subset['Revenue generated'],
            name=product_type,
            marker_color=colors[i]
        ),
        row=1, col=1
    )

# Plot for total revenue without legend
for i, product_type in enumerate(revenue_sum_by_demo_prod['Product type'].unique()):
    subset = revenue_sum_by_demo_prod[revenue_sum_by_demo_prod['Product type'] == product_type]
    fig.add_trace(
        go.Bar(
            x=subset['Customer demographics'],
            y=subset['Revenue generated'],
            showlegend=False,  # Hide legend for this subplot
            marker_color=colors[i]
        ),
        row=1, col=2
    )

# Beautify the subplot and show the legend for the first subplot
fig.update_layout(
    title='Revenue Analysis by Customer Demographics and Product Type',
    xaxis=dict(title='Customer Demographics'),
    yaxis=dict(title='Revenue'),
    xaxis2=dict(title='Customer Demographics'),
    yaxis2=dict(title='Revenue'),
    title_x=0.5,
    showlegend=True  # Show legend for the first subplot
)

# Show the subplot
fig.show()
# Out:
# <div>                            <div id="6860b62a-a854-4d64-9033-14fb61feddb7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6860b62a-a854-4d64-9033-14fb61feddb7")) {                    Plotly.newPlot(                        "6860b62a-a854-4d64-9033-14fb61feddb7",                        [{"marker":{"color":"rgb(141,211,199)"},"name":"cosmetics","x":["Female","Male","Non-binary","Unknown"],"y":[6954.854219685358,5347.7413743343,5247.096332116826,6335.182377815462],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(255,255,179)"},"name":"haircare","x":["Female","Male","Non-binary","Unknown"],"y":[6362.416641586338,5059.992730921369,5567.306726391122,4810.63219522254],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(190,186,218)"},"name":"skincare","x":["Female","Male","Non-binary","Unknown"],"y":[6095.470280123415,7806.214493320447,4650.8338885715775,6287.152695992038],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(141,211,199)"},"showlegend":false,"x":["Female","Male","Non-binary","Unknown"],"y":[69548.54219685358,21390.9654973372,26235.48166058413,44346.27664470823],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"rgb(255,255,179)"},"showlegend":false,"x":["Female","Male","Non-binary","Unknown"],"y":[12724.833283172677,50599.927309213694,38971.14708473785,72159.4829283381],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"rgb(190,186,218)"},"showlegend":false,"x":["Female","Male","Non-binary","Unknown"],"y":[79241.1136416044,54643.50145324313,51159.17277428735,56584.374263928345],"type":"bar","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"color ...

# %% [markdown]
# ### Lead times optimization analysis

# %%
avg_lead_times_transport = supply_data.groupby(['Transportation modes'])['Lead times'].mean().reset_index()

fig = px.bar(avg_lead_times_transport, x='Transportation modes', y='Lead times',
             labels={'Transportation modes': 'Transportation Mode', 'Lead times': 'Average Lead Time'},
             title='Average Lead Times by Transportation Mode')

# Customize the color scale for bars
color_scale = px.colors.qualitative.Set3  # You can choose a different color scale
fig.update_traces(marker_color=color_scale)

# Customize the layout for beautification
fig.update_layout(
    title=dict(text='Average Lead Times by Transportation Mode', x=0.5),
    xaxis_title='Transportation Mode',
    yaxis_title='Average Lead Time',
    xaxis_tickangle=-45,  # Rotate x-axis labels for better readability
    font=dict(family="Arial", size=14),
    showlegend=False  # Remove legend
)

# Show the plot
fig.show()
# Out:
# <div>                            <div id="a6979be0-a29d-4132-9cbb-b5f0f936232b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a6979be0-a29d-4132-9cbb-b5f0f936232b")) {                    Plotly.newPlot(                        "a6979be0-a29d-4132-9cbb-b5f0f936232b",                        [{"alignmentgroup":"True","hovertemplate":"Transportation Mode=%{x}\u003cbr\u003eAverage Lead Time=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":["rgb(141,211,199)","rgb(255,255,179)","rgb(190,186,218)","rgb(251,128,114)","rgb(128,177,211)","rgb(253,180,98)","rgb(179,222,105)","rgb(252,205,229)","rgb(217,217,217)","rgb(188,128,189)","rgb(204,235,197)","rgb(255,237,111)"],"pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Air","Rail","Road","Sea"],"xaxis":"x","y":[18.26923076923077,14.892857142857142,17.137931034482758,12.176470588235293],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"er ...

# %%
best_transportation_mode = avg_lead_times_transport.loc[avg_lead_times_transport['Lead times'].idxmin()]
best_transportation_mode
# Out:
# Transportation modes          Sea
# Lead times              12.176471
# Name: 3, dtype: object

# %%
best_transportation_data = supply_data[supply_data['Transportation modes']==best_transportation_mode['Transportation modes']]
best_transportation_data.head()
# Out:
#    Product type    SKU      Price  Availability  Number of products sold  \
# 6      skincare   SKU6   4.078333            48                       65
# 8     cosmetics   SKU8  68.717597            78                      150
# 15     skincare  SKU15  36.989245            94                      469
# 18     haircare  SKU18  36.443628            23                      620
# 27    cosmetics  SKU27  92.557361            42                      352
#
#     Revenue generated Customer demographics  Stock levels  Lead times  \
# 6         7823.476560                  Male            11          15
# 8         7517.363211                Female             5          10
# 15        5442.086785            Non-binary             9           8
# 18        9364.673505               Unknown            10          10
# 27        2686.457224               Unknown            47           9
#
#     Order quantities  ...  Lead time Production volumes  \
# 6                 58  ...         14                314
# 8                 15  ...         13                769
# 15                69  ...         14                580
# 18                46  ...         18                374
# 27                62  ...         25                291
#
#     Manufacturing lead time Manufacturing costs Inspection results  \
# 6                        24            1.085069            Pending
# 8                         8           11.423027            Pending
# 15                        7           97.121282               Pass
# 18                       17           27.107981            Pending
# 27                        4           10.528245               Fail
#
#     Defect rates  Transportation modes   Routes       Costs   EOQ
# 6       1.000911                   Sea  Route A  134.369097  37.0
# 8       2.709863                   Sea  Route B  505.557134  71.0
# 15      2.264406                   Sea  Route B  127.861800  36.0
# 18      2.231939                   Sea  Route A  593.480259  77.0
# 27      2.864668                   Sea  Route B  762.459182  87.0
#
# [5 rows x 25 columns]

# %%
import plotly.express as px

avg_lead_times_route = supply_data.groupby(['Routes'])['Lead times'].mean().reset_index()

# Assuming you have the avg_lead_times_route DataFrame already defined
fig = px.bar(avg_lead_times_route, x='Routes', y='Lead times',
             labels={'Routes': 'Route', 'Lead times': 'Average Lead Time'},
             title='Average Lead Times by Route')

# Customize the color scale for bars
color_scale = px.colors.qualitative.Set3  # You can choose a different color scale
fig.update_traces(marker_color=color_scale)

# Customize the layout for beautification
fig.update_layout(
    title=dict(text='Average Lead Times by Route', x=0.5),
    xaxis_title='Route',
    yaxis_title='Average Lead Time',
    xaxis_tickangle=-45,  # Rotate x-axis labels for better readability
    font=dict(family="Arial", size=14),
    showlegend=False  # Remove legend
)

# Show the plot
fig.show()
# Out:
# <div>                            <div id="439e7b73-06a2-463e-b216-787a52d2c0b3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("439e7b73-06a2-463e-b216-787a52d2c0b3")) {                    Plotly.newPlot(                        "439e7b73-06a2-463e-b216-787a52d2c0b3",                        [{"alignmentgroup":"True","hovertemplate":"Route=%{x}\u003cbr\u003eAverage Lead Time=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":["rgb(141,211,199)","rgb(255,255,179)","rgb(190,186,218)","rgb(251,128,114)","rgb(128,177,211)","rgb(253,180,98)","rgb(179,222,105)","rgb(252,205,229)","rgb(217,217,217)","rgb(188,128,189)","rgb(204,235,197)","rgb(255,237,111)"],"pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Route A","Route B","Route C"],"xaxis":"x","y":[14.69767441860465,17.216216216216218,16.35],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"col ...

# %%
best_route = avg_lead_times_route.loc[avg_lead_times_route['Lead times'].idxmin()]
best_route
# Out:
# Routes          Route A
# Lead times    14.697674
# Name: 0, dtype: object

# %%
best_route_data = supply_data[supply_data['Routes']==best_route['Routes']]
best_route_data.head()
# Out:
#    Product type    SKU      Price  Availability  Number of products sold  \
# 3      skincare   SKU3  61.163343            68                       83
# 4      skincare   SKU4   4.805496            26                      871
# 5      haircare   SKU5   1.699976            87                      147
# 6      skincare   SKU6   4.078333            48                       65
# 11     skincare  SKU11  90.635460            95                      960
#
#     Revenue generated Customer demographics  Stock levels  Lead times  \
# 3         7766.836426            Non-binary            23          13
# 4         2686.505152            Non-binary             5           3
# 5         2828.348746            Non-binary            90          27
# 6         7823.476560                  Male            11          15
# 11        6099.944116                Female            46          23
#
#     Order quantities  ...  Lead time Production volumes  \
# 3                 59  ...         24                937
# 4                 56  ...          5                414
# 5                 66  ...         10                104
# 6                 58  ...         14                314
# 11                60  ...         28                362
#
#     Manufacturing lead time Manufacturing costs Inspection results  \
# 3                        18           35.624741               Fail
# 4                         3           92.065161               Fail
# 5                        17           56.766476               Fail
# 6                        24            1.085069            Pending
# 11                       11           27.592363            Pending
#
#     Defect rates  Transportation modes   Routes       Costs   EOQ
# 3       4.746649                  Rail  Route A  254.776159  50.0
# 4       3.145580                   Air  Route A  923.440632  96.0
# 5       2.779194                  Road  Route A  235.461237  49.0
# 6       1.000911                   Sea  Route A  134.369097  37.0
# 11      0.021170                   Air  Route A  126.723033  36.0
#
# [5 rows x 25 columns]

# %% [markdown]
# # Modelling

# %% [markdown]
# ### Forecasting demand

# %%
X = supply_data.loc[:,['Price', 'Availability', 'Stock levels', 'Lead times', 'Order quantities']]
y = supply_data.loc[:,'Number of products sold']

# %%
# Define the number of folds for cross-validation
num_folds = 10

# %%
# Initialize lists to store evaluation metrics
mse_scores = []
rmse_scores = []
mae_scores = []
r2_scores = []

# %%
from sklearn.model_selection import KFold

# Create a KFold object
kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)

# %%
# Define the parameters for LightGBM
params = {
    'objective': 'regression',
    'metric': 'mean_squared_error',
    'boosting_type': 'gbdt',
    'num_leaves': 31,
    'learning_rate': 0.05,
    'feature_fraction': 0.9
}

# %%
import lightgbm as lgb
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Create LightGBM datasets for training and testing
    train_data = lgb.Dataset(X_train, label=y_train)
    test_data = lgb.Dataset(X_test, label=y_test, reference=train_data)
    
    # Add early stopping
    num_round = 100  # Increase the number of boosting rounds
    early_stopping_rounds = 5  # Set the number of rounds to wait for early stopping

    # Train the model with early stopping
    bst = lgb.train(
        params,
        train_data,
        num_round,
        valid_sets=[test_data],
        early_stopping_rounds=early_stopping_rounds,
        verbose_eval=10
    )
    
    # Make predictions on the test set
    y_pred = bst.predict(X_test, num_iteration=bst.best_iteration)

    # Calculate metrics
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    # Calculate the target range
    target_range = np.max(y_test) - np.min(y_test)

    # Calculate metrics as percentages
    percentage_mse = (mse / target_range) * 100
    percentage_rmse = (rmse / target_range) * 100
    percentage_mae = (mae / target_range) * 100
    percentage_r2 = (r2 * 100)

    # Append the scores to the respective lists
    mse_scores.append(percentage_mse)
    rmse_scores.append(percentage_rmse)
    mae_scores.append(percentage_mae)
    r2_scores.append(percentage_r2)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002267 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 135
# [LightGBM] [Info] Number of data points in the train set: 90, number of used features: 5
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 449.877778
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 5 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [1]	valid_0's l2: 152909
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000418 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 137
# [LightGBM] [Info] Number of data points in the train set: 90, number of used features: 5
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 465.177778
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 5 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [3]	valid_0's l2: 42338.7
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000434 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 134
# [LightGBM] [Info] Number of data points in the train set: 90, number of used features: 5
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 449.533333
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 5 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	valid_0's l2: 75638.8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [14]	valid_0's l2: 75013.7
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000654 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 134
# [LightGBM] [Info] Number of data points in the train set: 90, number of used features: 5
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 462.877778
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 5 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [1]	valid_0's l2: 95404.3
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000386 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 133
# [LightGBM] [Info] Number of data points in the train set: 90, number of used features: 5
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 470.288889
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 5 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [1]	valid_0's l2: 58352.6
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000284 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 136
# [LightGBM] [Info] Number of data points in the train set: 90, number of used features: 5
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 473.155556
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 5 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [1]	valid_0's l2: 137452
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000436 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 136
# [LightGBM] [Info] Number of data points in the train set: 90, number of used features: 5
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 464.577778
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 5 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [4]	valid_0's l2: 76462.3
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000382 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 135
# [LightGBM] [Info] Number of data points in the train set: 90, number of used features: 5
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 454.688889
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 5 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [1]	valid_0's l2: 122894
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000394 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 136
# [LightGBM] [Info] Number of data points in the train set: 90, number of used features: 5
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 459.822222
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 5 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [2]	valid_0's l2: 94322.5
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000407 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 135
# [LightGBM] [Info] Number of data points in the train set: 90, number of used features: 5
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 459.900000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 5 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	valid_0's l2: 62553.3
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [20]	valid_0's l2: 59845.7
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [30]	valid_0's l2: 57732.8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [40]	valid_0's l2: 56213.2
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [50]	valid_0's l2: 55133.7
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [60]	valid_0's l2: 55135.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [57]	valid_0's l2: 54910.1

# %%
# Calculate the average scores over all folds
avg_mse = np.mean(mse_scores)
avg_rmse = np.mean(rmse_scores)
avg_mae = np.mean(mae_scores)
avg_r2 = np.mean(r2_scores)

# Print the results
print(f"Average Mean Squared Error: {avg_mse:.2f}%")
print(f"Average Root Mean Squared Error: {avg_rmse:.2f}%")
print(f"Average Mean Absolute Error: {avg_mae:.2f}%")
print(f"Average R-squared: {avg_r2:.2f}%")
# Out:
# Average Mean Squared Error: 10450.61%
# Average Root Mean Squared Error: 34.70%
# Average Mean Absolute Error: 31.02%
# Average R-squared: -4.64%

# %% [markdown]
# ### Cost optimization

# %%
# Extract the features (X) and target (y)
X = supply_data.loc[:, 'Production volumes'].values.reshape(-1, 1)
y = supply_data.loc[:, 'Manufacturing costs'].values

# %%
# Define the number of folds for cross-validation
num_folds = 5

# %%
# Initialize lists to store evaluation metrics
mse_scores = []
rmse_scores = []
mae_scores = []
r2_scores = []

# %%
from sklearn.preprocessing import MinMaxScaler

# Initialize and fit the scaler to the data
scaler = MinMaxScaler()
scaler.fit(X)
# Out:
# MinMaxScaler()

# %%
# Create a KFold object
kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # Scale the data
    X_train_scaled = scaler.transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    # Define and compile the neural network model
    model = tf.keras.Sequential([
        Dense(64, activation='relu', input_dim=1),
        Dense(32, activation='relu'),
        Dense(1)
    ])

    model.compile(optimizer='adam', loss='mean_squared_error')
    
    # Define Early Stopping callback
    early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

    # Define Model Checkpoint callback to save the best model
    model_checkpoint = ModelCheckpoint('/kaggle/working/best_model.h5', save_best_only=True, save_weights_only=True, monitor='val_loss', mode='min')

    # Train the model on the training data with callbacks
    history = model.fit(X_train_scaled,
                        y_train, epochs=100,
                        batch_size=32,
                        validation_data=(X_test_scaled, y_test),
                        callbacks=[early_stopping, model_checkpoint])

    # Load the best model weights from the saved checkpoint
    model.load_weights('/kaggle/working/best_model.h5')
    
    # Make predictions on the test set
    y_pred = model.predict(X_test_scaled)
    
    # Calculate metrics
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    mae = np.mean(np.abs(y_test - y_pred))
    r2 = r2_score(y_test, y_pred)

    # Calculate metrics as percentages
    target_range = np.max(y_test) - np.min(y_test)
    percentage_mse = (mse / target_range) * 100
    percentage_rmse = (rmse / target_range) * 100
    percentage_mae = (mae / target_range) * 100
    percentage_r2 = (r2 * 100)

    # Append the scores to the respective lists
    mse_scores.append(percentage_mse)
    rmse_scores.append(percentage_rmse)
    mae_scores.append(percentage_mae)
    r2_scores.append(percentage_r2)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 1s 135ms/step - loss: 2898.4832 - val_loss: 3694.6145
# Epoch 2/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2892.9946 - val_loss: 3689.0591
# Epoch 3/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2888.5293 - val_loss: 3684.1577
# Epoch 4/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2884.4382 - val_loss: 3679.4800
# Epoch 5/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2880.4324 - val_loss: 3674.7524
# Epoch 6/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2876.5325 - val_loss: 3669.9207
# Epoch 7/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2872.4370 - val_loss: 3664.8394
# Epoch 8/100
# 3/3 [==============================] - 0s 23ms/step - loss: 2867.9312 - val_loss: 3659.5444
# Epoch 9/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2863.4207 - val_loss: 3653.9915
# Epoch 10/100
# 3/3 [==============================] - 0s 23ms/step - loss: 2858.5757 - val_loss: 3648.0527
# Epoch 11/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2853.4673 - val_loss: 3641.6199
# Epoch 12/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2848.1040 - val_loss: 3634.6792
# Epoch 13/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2841.9492 - val_loss: 3627.2715
# Epoch 14/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2835.6577 - val_loss: 3619.2612
# Epoch 15/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2828.6743 - val_loss: 3610.6516
# Epoch 16/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2821.1646 - val_loss: 3601.3853
# Epoch 17/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2813.4324 - val_loss: 3591.3503
# Epoch 18/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2804.8398 - val_loss: 3580.6040
# Epoch 19/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2795.5122 - val_loss: 3569.1106
# Epoch 20/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2785.7500 - val_loss: 3556.7651
# Epoch 21/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2775.4917 - val_loss: 3543.5144
# Epoch 22/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2764.1077 - val_loss: 3529.4094
# Epoch 23/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2751.7988 - val_loss: 3514.3569
# Epoch 24/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2738.9761 - val_loss: 3498.2515
# Epoch 25/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2725.0679 - val_loss: 3481.0688
# Epoch 26/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2710.3181 - val_loss: 3462.6719
# Epoch 27/100
# 3/3 [==============================] - 0s 27ms/step - loss: 2694.3687 - val_loss: 3443.0347
# Epoch 28/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2678.1484 - val_loss: 3421.9832
# Epoch 29/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2659.9707 - val_loss: 3399.6633
# Epoch 30/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2641.5752 - val_loss: 3375.9282
# Epoch 31/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2621.5334 - val_loss: 3351.1899
# Epoch 32/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2599.9612 - val_loss: 3325.3489
# Epoch 33/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2577.9749 - val_loss: 3297.9185
# Epoch 34/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2555.3081 - val_loss: 3268.8120
# Epoch 35/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2530.5864 - val_loss: 3238.2566
# Epoch 36/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2505.3977 - val_loss: 3206.1350
# Epoch 37/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2478.7085 - val_loss: 3172.7971
# Epoch 38/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2450.1782 - val_loss: 3138.2893
# Epoch 39/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2422.5845 - val_loss: 3102.0894
# Epoch 40/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2391.8074 - val_loss: 3064.8125
# Epoch 41/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2360.6362 - val_loss: 3025.9197
# Epoch 42/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2328.2908 - val_loss: 2985.5508
# Epoch 43/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2294.3452 - val_loss: 2943.8550
# Epoch 44/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2260.5605 - val_loss: 2900.4783
# Epoch 45/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2225.0400 - val_loss: 2855.6726
# Epoch 46/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2188.0044 - val_loss: 2809.6199
# Epoch 47/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2150.7197 - val_loss: 2762.5715
# Epoch 48/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2112.2202 - val_loss: 2714.6560
# Epoch 49/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2073.8591 - val_loss: 2665.5554
# Epoch 50/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2033.8347 - val_loss: 2615.6382
# Epoch 51/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1992.4163 - val_loss: 2565.0815
# Epoch 52/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1952.6101 - val_loss: 2512.9514
# Epoch 53/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1911.1575 - val_loss: 2459.7266
# Epoch 54/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1868.0160 - val_loss: 2405.7605
# Epoch 55/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1826.0277 - val_loss: 2350.8120
# Epoch 56/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1782.4744 - val_loss: 2295.7649
# Epoch 57/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1738.5569 - val_loss: 2240.1021
# Epoch 58/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1696.8857 - val_loss: 2183.5076
# Epoch 59/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1651.7122 - val_loss: 2127.1765
# Epoch 60/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1611.5558 - val_loss: 2070.1050
# Epoch 61/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1566.4663 - val_loss: 2014.5730
# Epoch 62/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1523.5164 - val_loss: 1959.2610
# Epoch 63/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1484.1438 - val_loss: 1903.8480
# Epoch 64/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1442.7355 - val_loss: 1849.7024
# Epoch 65/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1404.8035 - val_loss: 1796.3033
# Epoch 66/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1364.2844 - val_loss: 1744.7336
# Epoch 67/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1327.0391 - val_loss: 1693.9697
# Epoch 68/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1291.2780 - val_loss: 1644.9320
# Epoch 69/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1255.9683 - val_loss: 1597.5621
# Epoch 70/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1223.4469 - val_loss: 1550.6895
# Epoch 71/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1195.8276 - val_loss: 1504.7703
# Epoch 72/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1163.8331 - val_loss: 1462.6663
# Epoch 73/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1138.0315 - val_loss: 1422.5964
# Epoch 74/100
# 3/3 [==============================] - 0s 24ms/step - loss: 1112.3650 - val_loss: 1385.5901
# Epoch 75/100
# 3/3 [==============================] - 0s 24ms/step - loss: 1090.3535 - val_loss: 1350.3601
# Epoch 76/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1065.5685 - val_loss: 1318.2058
# Epoch 77/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1047.7155 - val_loss: 1286.4958
# Epoch 78/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1029.5271 - val_loss: 1256.6656
# Epoch 79/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1012.0609 - val_loss: 1229.4954
# Epoch 80/100
# 3/3 [==============================] - 0s 19ms/step - loss: 997.8878 - val_loss: 1203.8191
# Epoch 81/100
# 3/3 [==============================] - 0s 19ms/step - loss: 982.7814 - val_loss: 1179.9362
# Epoch 82/100
# 3/3 [==============================] - 0s 20ms/step - loss: 970.7172 - val_loss: 1156.8938
# Epoch 83/100
# 3/3 [==============================] - 0s 19ms/step - loss: 959.9365 - val_loss: 1135.4509
# Epoch 84/100
# 3/3 [==============================] - 0s 18ms/step - loss: 951.1795 - val_loss: 1115.7283
# Epoch 85/100
# 3/3 [==============================] - 0s 19ms/step - loss: 943.8363 - val_loss: 1098.2307
# Epoch 86/100
# 3/3 [==============================] - 0s 18ms/step - loss: 933.7870 - val_loss: 1084.2189
# Epoch 87/100
# 3/3 [==============================] - 0s 19ms/step - loss: 929.2108 - val_loss: 1070.7815
# Epoch 88/100
# 3/3 [==============================] - 0s 19ms/step - loss: 923.6048 - val_loss: 1059.2402
# Epoch 89/100
# 3/3 [==============================] - 0s 19ms/step - loss: 918.8843 - val_loss: 1048.7068
# Epoch 90/100
# 3/3 [==============================] - 0s 19ms/step - loss: 915.4870 - val_loss: 1038.4092
# Epoch 91/100
# 3/3 [==============================] - 0s 19ms/step - loss: 911.8161 - val_loss: 1029.2122
# Epoch 92/100
# 3/3 [==============================] - 0s 19ms/step - loss: 908.8125 - val_loss: 1020.9747
# Epoch 93/100
# 3/3 [==============================] - 0s 20ms/step - loss: 906.4639 - val_loss: 1013.3810
# Epoch 94/100
# 3/3 [==============================] - 0s 19ms/step - loss: 904.6896 - val_loss: 1006.2256
# Epoch 95/100
# 3/3 [==============================] - 0s 19ms/step - loss: 902.6281 - val_loss: 1000.0365
# Epoch 96/100
# 3/3 [==============================] - 0s 19ms/step - loss: 900.9449 - val_loss: 994.7783
# Epoch 97/100
# 3/3 [==============================] - 0s 19ms/step - loss: 899.7883 - val_loss: 989.8719
# Epoch 98/100
# 3/3 [==============================] - 0s 19ms/step - loss: 899.6349 - val_loss: 984.6660
# Epoch 99/100
# 3/3 [==============================] - 0s 19ms/step - loss: 897.9998 - val_loss: 980.8431
# Epoch 100/100
# 3/3 [==============================] - 0s 19ms/step - loss: 896.9535 - val_loss: 977.8926
# 1/1 [==============================] - 0s 120ms/step
# Epoch 1/100
# 3/3 [==============================] - 1s 80ms/step - loss: 2955.0757 - val_loss: 3446.9668
# Epoch 2/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2951.3293 - val_loss: 3443.0220
# Epoch 3/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2947.3496 - val_loss: 3438.8984
# Epoch 4/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2943.5291 - val_loss: 3434.4902
# Epoch 5/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2939.1404 - val_loss: 3429.8621
# Epoch 6/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2934.5776 - val_loss: 3424.7488
# Epoch 7/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2929.7793 - val_loss: 3419.1960
# Epoch 8/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2924.0669 - val_loss: 3413.2351
# Epoch 9/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2918.4290 - val_loss: 3406.7390
# Epoch 10/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2912.2441 - val_loss: 3399.7505
# Epoch 11/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2905.6074 - val_loss: 3392.2876
# Epoch 12/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2898.3586 - val_loss: 3384.3267
# Epoch 13/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2890.4968 - val_loss: 3375.8062
# Epoch 14/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2882.1790 - val_loss: 3366.5950
# Epoch 15/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2873.3511 - val_loss: 3356.6079
# Epoch 16/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2863.5259 - val_loss: 3345.8516
# Epoch 17/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2853.2952 - val_loss: 3334.2117
# Epoch 18/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2842.0190 - val_loss: 3321.6802
# Epoch 19/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2830.1831 - val_loss: 3308.1804
# Epoch 20/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2817.0994 - val_loss: 3293.8140
# Epoch 21/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2803.1589 - val_loss: 3278.4258
# Epoch 22/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2788.3594 - val_loss: 3261.8901
# Epoch 23/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2772.6938 - val_loss: 3244.2615
# Epoch 24/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2755.5269 - val_loss: 3225.5442
# Epoch 25/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2737.8850 - val_loss: 3205.4636
# Epoch 26/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2718.9849 - val_loss: 3184.0500
# Epoch 27/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2698.4214 - val_loss: 3161.4277
# Epoch 28/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2677.0886 - val_loss: 3137.5691
# Epoch 29/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2654.1245 - val_loss: 3112.4780
# Epoch 30/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2630.6997 - val_loss: 3085.8220
# Epoch 31/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2605.7454 - val_loss: 3057.9038
# Epoch 32/100
# 3/3 [==============================] - 0s 23ms/step - loss: 2579.8828 - val_loss: 3028.8376
# Epoch 33/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2551.2554 - val_loss: 2998.5664
# Epoch 34/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2523.7017 - val_loss: 2966.2830
# Epoch 35/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2492.2083 - val_loss: 2932.6995
# Epoch 36/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2460.6445 - val_loss: 2897.2117
# Epoch 37/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2427.6177 - val_loss: 2859.9360
# Epoch 38/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2391.6021 - val_loss: 2821.2004
# Epoch 39/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2356.1948 - val_loss: 2780.7080
# Epoch 40/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2317.4229 - val_loss: 2739.1040
# Epoch 41/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2280.5000 - val_loss: 2695.5605
# Epoch 42/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2238.9326 - val_loss: 2651.0806
# Epoch 43/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2198.4700 - val_loss: 2605.1763
# Epoch 44/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2155.9692 - val_loss: 2558.2407
# Epoch 45/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2112.7341 - val_loss: 2509.9312
# Epoch 46/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2070.2925 - val_loss: 2460.3906
# Epoch 47/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2023.2375 - val_loss: 2410.7532
# Epoch 48/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1977.4441 - val_loss: 2359.8972
# Epoch 49/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1931.4945 - val_loss: 2307.6821
# Epoch 50/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1883.5726 - val_loss: 2254.5840
# Epoch 51/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1837.0176 - val_loss: 2200.7466
# Epoch 52/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1789.2158 - val_loss: 2146.7910
# Epoch 53/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1739.7256 - val_loss: 2092.4565
# Epoch 54/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1691.9417 - val_loss: 2037.9791
# Epoch 55/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1643.1853 - val_loss: 1984.4001
# Epoch 56/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1598.3669 - val_loss: 1930.9482
# Epoch 57/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1547.9958 - val_loss: 1878.8191
# Epoch 58/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1505.6619 - val_loss: 1825.7914
# Epoch 59/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1455.9388 - val_loss: 1774.1963
# Epoch 60/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1412.3063 - val_loss: 1723.0570
# Epoch 61/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1370.1982 - val_loss: 1673.1061
# Epoch 62/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1326.2600 - val_loss: 1625.1514
# Epoch 63/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1290.4041 - val_loss: 1577.7050
# Epoch 64/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1247.8164 - val_loss: 1533.1788
# Epoch 65/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1214.1478 - val_loss: 1489.7950
# Epoch 66/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1177.6381 - val_loss: 1449.4912
# Epoch 67/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1147.7041 - val_loss: 1410.7510
# Epoch 68/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1116.6104 - val_loss: 1374.8669
# Epoch 69/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1088.9802 - val_loss: 1341.3337
# Epoch 70/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1062.5947 - val_loss: 1310.5826
# Epoch 71/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1041.2579 - val_loss: 1281.9141
# Epoch 72/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1019.4113 - val_loss: 1256.0051
# Epoch 73/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1002.1064 - val_loss: 1231.6996
# Epoch 74/100
# 3/3 [==============================] - 0s 18ms/step - loss: 984.9832 - val_loss: 1209.7185
# Epoch 75/100
# 3/3 [==============================] - 0s 18ms/step - loss: 968.6259 - val_loss: 1190.3767
# Epoch 76/100
# 3/3 [==============================] - 0s 18ms/step - loss: 956.9313 - val_loss: 1172.0199
# Epoch 77/100
# 3/3 [==============================] - 0s 19ms/step - loss: 944.7482 - val_loss: 1155.3267
# Epoch 78/100
# 3/3 [==============================] - 0s 19ms/step - loss: 936.3372 - val_loss: 1140.0201
# Epoch 79/100
# 3/3 [==============================] - 0s 19ms/step - loss: 926.1014 - val_loss: 1126.9989
# Epoch 80/100
# 3/3 [==============================] - 0s 19ms/step - loss: 919.3682 - val_loss: 1114.9104
# Epoch 81/100
# 3/3 [==============================] - 0s 19ms/step - loss: 914.8307 - val_loss: 1104.2819
# Epoch 82/100
# 3/3 [==============================] - 0s 18ms/step - loss: 907.9451 - val_loss: 1096.2045
# Epoch 83/100
# 3/3 [==============================] - 0s 18ms/step - loss: 904.4087 - val_loss: 1088.6207
# Epoch 84/100
# 3/3 [==============================] - 0s 19ms/step - loss: 902.5666 - val_loss: 1081.4691
# Epoch 85/100
# 3/3 [==============================] - 0s 18ms/step - loss: 898.9349 - val_loss: 1076.0864
# Epoch 86/100
# 3/3 [==============================] - 0s 19ms/step - loss: 896.4232 - val_loss: 1071.7469
# Epoch 87/100
# 3/3 [==============================] - 0s 19ms/step - loss: 895.1094 - val_loss: 1067.5002
# Epoch 88/100
# 3/3 [==============================] - 0s 19ms/step - loss: 894.0286 - val_loss: 1063.5667
# Epoch 89/100
# 3/3 [==============================] - 0s 19ms/step - loss: 892.5807 - val_loss: 1060.1444
# Epoch 90/100
# 3/3 [==============================] - 0s 24ms/step - loss: 891.7619 - val_loss: 1056.8300
# Epoch 91/100
# 3/3 [==============================] - 0s 21ms/step - loss: 890.6584 - val_loss: 1053.6792
# Epoch 92/100
# 3/3 [==============================] - 0s 21ms/step - loss: 889.9134 - val_loss: 1050.8408
# Epoch 93/100
# 3/3 [==============================] - 0s 21ms/step - loss: 889.1075 - val_loss: 1048.5334
# Epoch 94/100
# 3/3 [==============================] - 0s 24ms/step - loss: 888.5065 - val_loss: 1046.3113
# Epoch 95/100
# 3/3 [==============================] - 0s 22ms/step - loss: 887.9518 - val_loss: 1044.0627
# Epoch 96/100
# 3/3 [==============================] - 0s 21ms/step - loss: 887.4762 - val_loss: 1041.8536
# Epoch 97/100
# 3/3 [==============================] - 0s 21ms/step - loss: 887.4382 - val_loss: 1039.3938
# Epoch 98/100
# 3/3 [==============================] - 0s 20ms/step - loss: 886.8078 - val_loss: 1037.4879
# Epoch 99/100
# 3/3 [==============================] - 0s 20ms/step - loss: 886.4393 - val_loss: 1035.5715
# Epoch 100/100
# 3/3 [==============================] - 0s 20ms/step - loss: 886.6979 - val_loss: 1033.3059
# 1/1 [==============================] - 0s 64ms/step
# Epoch 1/100
# 3/3 [==============================] - 1s 89ms/step - loss: 3191.3215 - val_loss: 2593.2568
# Epoch 2/100
# 3/3 [==============================] - 0s 21ms/step - loss: 3184.8970 - val_loss: 2588.1196
# Epoch 3/100
# 3/3 [==============================] - 0s 22ms/step - loss: 3178.8386 - val_loss: 2583.0466
# Epoch 4/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3172.7903 - val_loss: 2577.9468
# Epoch 5/100
# 3/3 [==============================] - 0s 18ms/step - loss: 3166.7114 - val_loss: 2572.8367
# Epoch 6/100
# 3/3 [==============================] - 0s 18ms/step - loss: 3160.3813 - val_loss: 2567.7983
# Epoch 7/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3154.2903 - val_loss: 2562.8677
# Epoch 8/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3148.4758 - val_loss: 2557.8423
# Epoch 9/100
# 3/3 [==============================] - 0s 18ms/step - loss: 3142.3633 - val_loss: 2552.6443
# Epoch 10/100
# 3/3 [==============================] - 0s 18ms/step - loss: 3135.8152 - val_loss: 2547.1133
# Epoch 11/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3129.1292 - val_loss: 2541.1152
# Epoch 12/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3121.7805 - val_loss: 2534.6895
# Epoch 13/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3113.7532 - val_loss: 2527.8547
# Epoch 14/100
# 3/3 [==============================] - 0s 18ms/step - loss: 3105.5454 - val_loss: 2520.5662
# Epoch 15/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3096.7773 - val_loss: 2512.8721
# Epoch 16/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3087.3296 - val_loss: 2504.5415
# Epoch 17/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3076.6489 - val_loss: 2495.4348
# Epoch 18/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3065.3247 - val_loss: 2485.5522
# Epoch 19/100
# 3/3 [==============================] - 0s 18ms/step - loss: 3053.2026 - val_loss: 2474.9038
# Epoch 20/100
# 3/3 [==============================] - 0s 18ms/step - loss: 3040.0042 - val_loss: 2463.4702
# Epoch 21/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3025.2759 - val_loss: 2451.2991
# Epoch 22/100
# 3/3 [==============================] - 0s 18ms/step - loss: 3010.6184 - val_loss: 2438.1692
# Epoch 23/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2994.1958 - val_loss: 2424.1782
# Epoch 24/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2977.1733 - val_loss: 2409.2458
# Epoch 25/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2958.4072 - val_loss: 2393.4167
# Epoch 26/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2939.2036 - val_loss: 2376.6284
# Epoch 27/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2918.0437 - val_loss: 2359.0012
# Epoch 28/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2896.4602 - val_loss: 2340.2935
# Epoch 29/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2872.3755 - val_loss: 2320.6582
# Epoch 30/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2849.6140 - val_loss: 2299.6406
# Epoch 31/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2821.9380 - val_loss: 2277.9526
# Epoch 32/100
# 3/3 [==============================] - 0s 23ms/step - loss: 2795.9990 - val_loss: 2254.9053
# Epoch 33/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2767.0852 - val_loss: 2230.9143
# Epoch 34/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2737.3809 - val_loss: 2205.8325
# Epoch 35/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2705.4595 - val_loss: 2179.6802
# Epoch 36/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2673.2378 - val_loss: 2152.2395
# Epoch 37/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2639.7290 - val_loss: 2123.6316
# Epoch 38/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2603.1892 - val_loss: 2094.1089
# Epoch 39/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2565.1069 - val_loss: 2063.5034
# Epoch 40/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2527.2136 - val_loss: 2031.5527
# Epoch 41/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2488.0459 - val_loss: 1998.5168
# Epoch 42/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2445.3879 - val_loss: 1965.0068
# Epoch 43/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2403.6191 - val_loss: 1930.7170
# Epoch 44/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2360.4426 - val_loss: 1895.5510
# Epoch 45/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2314.2603 - val_loss: 1860.0781
# Epoch 46/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2270.2300 - val_loss: 1823.8734
# Epoch 47/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2223.7446 - val_loss: 1787.3269
# Epoch 48/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2175.9912 - val_loss: 1750.4656
# Epoch 49/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2129.3171 - val_loss: 1712.9202
# Epoch 50/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2079.6099 - val_loss: 1675.4324
# Epoch 51/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2031.9594 - val_loss: 1637.5941
# Epoch 52/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1983.6263 - val_loss: 1599.6509
# Epoch 53/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1931.1957 - val_loss: 1562.3857
# Epoch 54/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1882.9847 - val_loss: 1524.8041
# Epoch 55/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1835.1804 - val_loss: 1487.1893
# Epoch 56/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1782.7424 - val_loss: 1450.7504
# Epoch 57/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1736.7754 - val_loss: 1414.7966
# Epoch 58/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1684.6501 - val_loss: 1380.3464
# Epoch 59/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1639.0930 - val_loss: 1346.5023
# Epoch 60/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1591.2312 - val_loss: 1313.7822
# Epoch 61/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1544.0415 - val_loss: 1281.7507
# Epoch 62/100
# 3/3 [==============================] - 0s 27ms/step - loss: 1498.3827 - val_loss: 1250.5223
# Epoch 63/100
# 3/3 [==============================] - 0s 25ms/step - loss: 1455.8215 - val_loss: 1220.3734
# Epoch 64/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1414.0939 - val_loss: 1191.9259
# Epoch 65/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1371.2620 - val_loss: 1166.0022
# Epoch 66/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1327.9154 - val_loss: 1142.2271
# Epoch 67/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1291.7797 - val_loss: 1119.2937
# Epoch 68/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1255.8735 - val_loss: 1097.7793
# Epoch 69/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1221.1414 - val_loss: 1077.9840
# Epoch 70/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1186.4087 - val_loss: 1060.1244
# Epoch 71/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1157.1376 - val_loss: 1043.5679
# Epoch 72/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1126.0818 - val_loss: 1029.0167
# Epoch 73/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1097.8381 - val_loss: 1016.2767
# Epoch 74/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1074.4441 - val_loss: 1004.9354
# Epoch 75/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1049.3276 - val_loss: 995.4583
# Epoch 76/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1027.9984 - val_loss: 987.6859
# Epoch 77/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1007.6714 - val_loss: 981.5856
# Epoch 78/100
# 3/3 [==============================] - 0s 19ms/step - loss: 992.0690 - val_loss: 976.8397
# Epoch 79/100
# 3/3 [==============================] - 0s 19ms/step - loss: 976.6337 - val_loss: 973.5021
# Epoch 80/100
# 3/3 [==============================] - 0s 19ms/step - loss: 963.4631 - val_loss: 971.3654
# Epoch 81/100
# 3/3 [==============================] - 0s 18ms/step - loss: 949.0668 - val_loss: 970.2791
# Epoch 82/100
# 3/3 [==============================] - 0s 19ms/step - loss: 938.7123 - val_loss: 970.0198
# Epoch 83/100
# 3/3 [==============================] - 0s 14ms/step - loss: 929.9274 - val_loss: 970.5208
# Epoch 84/100
# 3/3 [==============================] - 0s 14ms/step - loss: 921.2325 - val_loss: 971.6760
# Epoch 85/100
# 3/3 [==============================] - 0s 15ms/step - loss: 914.0612 - val_loss: 973.4142
# Epoch 86/100
# 3/3 [==============================] - 0s 15ms/step - loss: 908.8540 - val_loss: 975.7013
# Epoch 87/100
# 3/3 [==============================] - 0s 15ms/step - loss: 903.7966 - val_loss: 978.3089
# 1/1 [==============================] - 0s 65ms/step
# Epoch 1/100
# 3/3 [==============================] - 1s 87ms/step - loss: 3070.7126 - val_loss: 2979.4824
# Epoch 2/100
# 3/3 [==============================] - 0s 21ms/step - loss: 3066.1909 - val_loss: 2974.7686
# Epoch 3/100
# 3/3 [==============================] - 0s 21ms/step - loss: 3061.4539 - val_loss: 2970.2734
# Epoch 4/100
# 3/3 [==============================] - 0s 20ms/step - loss: 3056.6487 - val_loss: 2965.8286
# Epoch 5/100
# 3/3 [==============================] - 0s 21ms/step - loss: 3052.3496 - val_loss: 2961.2788
# Epoch 6/100
# 3/3 [==============================] - 0s 20ms/step - loss: 3047.7446 - val_loss: 2956.5249
# Epoch 7/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3042.9749 - val_loss: 2951.5278
# Epoch 8/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3037.6401 - val_loss: 2946.2168
# Epoch 9/100
# 3/3 [==============================] - 0s 18ms/step - loss: 3032.1086 - val_loss: 2940.5259
# Epoch 10/100
# 3/3 [==============================] - 0s 18ms/step - loss: 3026.4937 - val_loss: 2934.4153
# Epoch 11/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3020.1768 - val_loss: 2927.9146
# Epoch 12/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3013.3777 - val_loss: 2920.9836
# Epoch 13/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3006.7017 - val_loss: 2913.4373
# Epoch 14/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2998.5325 - val_loss: 2905.2183
# Epoch 15/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2989.8728 - val_loss: 2896.3030
# Epoch 16/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2981.2058 - val_loss: 2886.6528
# Epoch 17/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2971.2395 - val_loss: 2876.4202
# Epoch 18/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2960.3840 - val_loss: 2865.5120
# Epoch 19/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2949.2798 - val_loss: 2853.8352
# Epoch 20/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2937.4153 - val_loss: 2841.3982
# Epoch 21/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2924.6628 - val_loss: 2828.1711
# Epoch 22/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2911.1555 - val_loss: 2814.0591
# Epoch 23/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2896.4521 - val_loss: 2799.0378
# Epoch 24/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2881.3594 - val_loss: 2783.0332
# Epoch 25/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2864.7507 - val_loss: 2766.1533
# Epoch 26/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2847.5183 - val_loss: 2748.2319
# Epoch 27/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2829.3931 - val_loss: 2729.1526
# Epoch 28/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2809.9324 - val_loss: 2709.0427
# Epoch 29/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2789.3645 - val_loss: 2687.8999
# Epoch 30/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2767.1414 - val_loss: 2665.5955
# Epoch 31/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2744.1853 - val_loss: 2641.9375
# Epoch 32/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2720.2092 - val_loss: 2616.9492
# Epoch 33/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2695.0732 - val_loss: 2590.6763
# Epoch 34/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2669.5754 - val_loss: 2563.1775
# Epoch 35/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2639.8406 - val_loss: 2534.9937
# Epoch 36/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2612.1897 - val_loss: 2505.2649
# Epoch 37/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2582.7583 - val_loss: 2474.4080
# Epoch 38/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2550.1743 - val_loss: 2442.7715
# Epoch 39/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2518.9358 - val_loss: 2409.6091
# Epoch 40/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2486.0308 - val_loss: 2375.1089
# Epoch 41/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2451.1147 - val_loss: 2339.6033
# Epoch 42/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2414.8630 - val_loss: 2303.1216
# Epoch 43/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2377.3535 - val_loss: 2265.5486
# Epoch 44/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2339.4563 - val_loss: 2226.6973
# Epoch 45/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2300.2241 - val_loss: 2186.5554
# Epoch 46/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2262.1558 - val_loss: 2145.0142
# Epoch 47/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2219.9185 - val_loss: 2103.2288
# Epoch 48/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2180.0857 - val_loss: 2060.7114
# Epoch 49/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2137.5466 - val_loss: 2018.1986
# Epoch 50/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2093.5925 - val_loss: 1975.5212
# Epoch 51/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2052.3789 - val_loss: 1931.8033
# Epoch 52/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2008.4957 - val_loss: 1887.5863
# Epoch 53/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1965.5857 - val_loss: 1842.5439
# Epoch 54/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1920.6813 - val_loss: 1797.5750
# Epoch 55/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1877.7393 - val_loss: 1752.3070
# Epoch 56/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1832.6877 - val_loss: 1707.4174
# Epoch 57/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1788.6683 - val_loss: 1662.6371
# Epoch 58/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1744.5853 - val_loss: 1618.0438
# Epoch 59/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1703.1898 - val_loss: 1573.3201
# Epoch 60/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1660.0608 - val_loss: 1529.3434
# Epoch 61/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1617.7551 - val_loss: 1486.3468
# Epoch 62/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1576.7727 - val_loss: 1444.3430
# Epoch 63/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1534.3103 - val_loss: 1403.6995
# Epoch 64/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1495.9800 - val_loss: 1363.1003
# Epoch 65/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1458.4003 - val_loss: 1322.9700
# Epoch 66/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1418.4714 - val_loss: 1284.2649
# Epoch 67/100
# 3/3 [==============================] - 0s 27ms/step - loss: 1384.1765 - val_loss: 1246.1411
# Epoch 68/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1346.7362 - val_loss: 1209.5706
# Epoch 69/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1315.0112 - val_loss: 1173.3253
# Epoch 70/100
# 3/3 [==============================] - 0s 24ms/step - loss: 1279.9050 - val_loss: 1138.9509
# Epoch 71/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1251.6572 - val_loss: 1105.4802
# Epoch 72/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1220.2356 - val_loss: 1074.6892
# Epoch 73/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1190.7113 - val_loss: 1045.9481
# Epoch 74/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1166.6627 - val_loss: 1018.1705
# Epoch 75/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1142.1364 - val_loss: 992.6336
# Epoch 76/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1121.3838 - val_loss: 968.4492
# Epoch 77/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1099.3737 - val_loss: 946.3400
# Epoch 78/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1083.2278 - val_loss: 925.4144
# Epoch 79/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1065.2826 - val_loss: 906.7390
# Epoch 80/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1048.7639 - val_loss: 889.8524
# Epoch 81/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1036.4993 - val_loss: 873.7936
# Epoch 82/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1021.5703 - val_loss: 859.5358
# Epoch 83/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1010.5571 - val_loss: 846.2191
# Epoch 84/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1001.6490 - val_loss: 834.0121
# Epoch 85/100
# 3/3 [==============================] - 0s 18ms/step - loss: 992.3851 - val_loss: 823.6052
# Epoch 86/100
# 3/3 [==============================] - 0s 18ms/step - loss: 985.0436 - val_loss: 814.4133
# Epoch 87/100
# 3/3 [==============================] - 0s 19ms/step - loss: 979.7454 - val_loss: 806.2321
# Epoch 88/100
# 3/3 [==============================] - 0s 18ms/step - loss: 972.8729 - val_loss: 799.5324
# Epoch 89/100
# 3/3 [==============================] - 0s 19ms/step - loss: 968.0024 - val_loss: 793.4918
# Epoch 90/100
# 3/3 [==============================] - 0s 19ms/step - loss: 964.9757 - val_loss: 788.0135
# Epoch 91/100
# 3/3 [==============================] - 0s 18ms/step - loss: 961.3492 - val_loss: 783.4084
# Epoch 92/100
# 3/3 [==============================] - 0s 19ms/step - loss: 957.6506 - val_loss: 779.2859
# Epoch 93/100
# 3/3 [==============================] - 0s 20ms/step - loss: 955.9671 - val_loss: 775.3190
# Epoch 94/100
# 3/3 [==============================] - 0s 18ms/step - loss: 952.8615 - val_loss: 772.0560
# Epoch 95/100
# 3/3 [==============================] - 0s 19ms/step - loss: 951.8777 - val_loss: 768.7634
# Epoch 96/100
# 3/3 [==============================] - 0s 19ms/step - loss: 950.6115 - val_loss: 766.1122
# Epoch 97/100
# 3/3 [==============================] - 0s 18ms/step - loss: 948.6381 - val_loss: 764.2294
# Epoch 98/100
# 3/3 [==============================] - 0s 18ms/step - loss: 947.4193 - val_loss: 762.7245
# Epoch 99/100
# 3/3 [==============================] - 0s 18ms/step - loss: 946.5861 - val_loss: 761.5013
# Epoch 100/100
# 3/3 [==============================] - 0s 18ms/step - loss: 945.7339 - val_loss: 760.6184
# 1/1 [==============================] - 0s 59ms/step
# Epoch 1/100
# 3/3 [==============================] - 1s 81ms/step - loss: 3189.0278 - val_loss: 2569.6907
# Epoch 2/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3184.2124 - val_loss: 2565.3914
# Epoch 3/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3180.1655 - val_loss: 2561.8752
# Epoch 4/100
# 3/3 [==============================] - 0s 18ms/step - loss: 3176.7231 - val_loss: 2558.9812
# Epoch 5/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3173.7656 - val_loss: 2556.1543
# Epoch 6/100
# 3/3 [==============================] - 0s 18ms/step - loss: 3170.8081 - val_loss: 2553.1794
# Epoch 7/100
# 3/3 [==============================] - 0s 18ms/step - loss: 3167.7390 - val_loss: 2550.0276
# Epoch 8/100
# 3/3 [==============================] - 0s 18ms/step - loss: 3164.3696 - val_loss: 2546.7214
# Epoch 9/100
# 3/3 [==============================] - 0s 18ms/step - loss: 3160.8813 - val_loss: 2543.2229
# Epoch 10/100
# 3/3 [==============================] - 0s 21ms/step - loss: 3157.1362 - val_loss: 2539.5112
# Epoch 11/100
# 3/3 [==============================] - 0s 22ms/step - loss: 3153.2651 - val_loss: 2535.4868
# Epoch 12/100
# 3/3 [==============================] - 0s 23ms/step - loss: 3148.9683 - val_loss: 2531.1675
# Epoch 13/100
# 3/3 [==============================] - 0s 23ms/step - loss: 3144.2212 - val_loss: 2526.5454
# Epoch 14/100
# 3/3 [==============================] - 0s 21ms/step - loss: 3139.4026 - val_loss: 2521.5798
# Epoch 15/100
# 3/3 [==============================] - 0s 20ms/step - loss: 3134.1980 - val_loss: 2516.2695
# Epoch 16/100
# 3/3 [==============================] - 0s 21ms/step - loss: 3128.4670 - val_loss: 2510.6514
# Epoch 17/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3122.3457 - val_loss: 2504.6187
# Epoch 18/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3116.0354 - val_loss: 2498.0957
# Epoch 19/100
# 3/3 [==============================] - 0s 25ms/step - loss: 3109.1479 - val_loss: 2491.1550
# Epoch 20/100
# 3/3 [==============================] - 0s 25ms/step - loss: 3101.4233 - val_loss: 2483.7771
# Epoch 21/100
# 3/3 [==============================] - 0s 22ms/step - loss: 3093.6482 - val_loss: 2475.8169
# Epoch 22/100
# 3/3 [==============================] - 0s 22ms/step - loss: 3084.9626 - val_loss: 2467.2781
# Epoch 23/100
# 3/3 [==============================] - 0s 23ms/step - loss: 3075.7981 - val_loss: 2458.1128
# Epoch 24/100
# 3/3 [==============================] - 0s 21ms/step - loss: 3065.7703 - val_loss: 2448.2937
# Epoch 25/100
# 3/3 [==============================] - 0s 21ms/step - loss: 3055.1396 - val_loss: 2437.7434
# Epoch 26/100
# 3/3 [==============================] - 0s 20ms/step - loss: 3043.8848 - val_loss: 2426.4543
# Epoch 27/100
# 3/3 [==============================] - 0s 20ms/step - loss: 3031.7026 - val_loss: 2414.4695
# Epoch 28/100
# 3/3 [==============================] - 0s 22ms/step - loss: 3018.6001 - val_loss: 2401.7500
# Epoch 29/100
# 3/3 [==============================] - 0s 20ms/step - loss: 3005.0676 - val_loss: 2388.2043
# Epoch 30/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2990.4146 - val_loss: 2373.8613
# Epoch 31/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2974.8101 - val_loss: 2358.6416
# Epoch 32/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2958.5793 - val_loss: 2342.5161
# Epoch 33/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2940.9304 - val_loss: 2325.5864
# Epoch 34/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2921.8862 - val_loss: 2307.7969
# Epoch 35/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2904.0188 - val_loss: 2288.7944
# Epoch 36/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2882.0254 - val_loss: 2269.1731
# Epoch 37/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2861.0249 - val_loss: 2248.3391
# Epoch 38/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2837.8501 - val_loss: 2226.5439
# Epoch 39/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2814.6824 - val_loss: 2203.6514
# Epoch 40/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2788.7532 - val_loss: 2179.9844
# Epoch 41/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2762.9082 - val_loss: 2155.2036
# Epoch 42/100
# 3/3 [==============================] - 0s 23ms/step - loss: 2735.9580 - val_loss: 2129.4534
# Epoch 43/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2707.6997 - val_loss: 2102.6648
# Epoch 44/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2677.5085 - val_loss: 2074.9133
# Epoch 45/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2647.7725 - val_loss: 2045.9945
# Epoch 46/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2615.7920 - val_loss: 2016.1980
# Epoch 47/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2582.8660 - val_loss: 1985.5642
# Epoch 48/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2549.4082 - val_loss: 1954.1506
# Epoch 49/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2515.3533 - val_loss: 1922.0260
# Epoch 50/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2478.4014 - val_loss: 1889.5315
# Epoch 51/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2440.4482 - val_loss: 1856.3398
# Epoch 52/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2403.3745 - val_loss: 1821.9524
# Epoch 53/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2365.8691 - val_loss: 1786.5618
# Epoch 54/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2326.8511 - val_loss: 1750.6146
# Epoch 55/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2285.6208 - val_loss: 1714.5950
# Epoch 56/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2243.9099 - val_loss: 1678.1934
# Epoch 57/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2203.7505 - val_loss: 1641.3024
# Epoch 58/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2160.9224 - val_loss: 1604.7988
# Epoch 59/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2117.5015 - val_loss: 1568.2242
# Epoch 60/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2076.6504 - val_loss: 1531.1516
# Epoch 61/100
# 3/3 [==============================] - 0s 23ms/step - loss: 2034.0872 - val_loss: 1494.2133
# Epoch 62/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1990.8265 - val_loss: 1457.6598
# Epoch 63/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1947.5813 - val_loss: 1421.4600
# Epoch 64/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1904.5804 - val_loss: 1385.3854
# Epoch 65/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1862.3660 - val_loss: 1349.4424
# Epoch 66/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1820.9348 - val_loss: 1313.9113
# Epoch 67/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1774.1816 - val_loss: 1279.9427
# Epoch 68/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1734.0615 - val_loss: 1245.8353
# Epoch 69/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1691.6199 - val_loss: 1212.3820
# Epoch 70/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1650.0765 - val_loss: 1179.5266
# Epoch 71/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1607.9896 - val_loss: 1147.5803
# Epoch 72/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1569.0741 - val_loss: 1116.6371
# Epoch 73/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1528.3412 - val_loss: 1087.4709
# Epoch 74/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1490.8646 - val_loss: 1059.4509
# Epoch 75/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1451.5522 - val_loss: 1032.9397
# Epoch 76/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1416.4209 - val_loss: 1007.1234
# Epoch 77/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1383.3080 - val_loss: 982.5231
# Epoch 78/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1346.8632 - val_loss: 960.3154
# Epoch 79/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1317.5743 - val_loss: 939.6636
# Epoch 80/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1284.7211 - val_loss: 921.1849
# Epoch 81/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1256.5007 - val_loss: 903.7778
# Epoch 82/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1228.2944 - val_loss: 887.7126
# Epoch 83/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1201.3616 - val_loss: 872.8470
# Epoch 84/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1176.6653 - val_loss: 859.0911
# Epoch 85/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1153.4714 - val_loss: 846.6774
# Epoch 86/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1128.0693 - val_loss: 835.9935
# Epoch 87/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1108.9231 - val_loss: 826.5482
# Epoch 88/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1088.5129 - val_loss: 818.8665
# Epoch 89/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1068.0525 - val_loss: 812.6538
# Epoch 90/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1053.0156 - val_loss: 807.3531
# Epoch 91/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1038.8054 - val_loss: 803.2853
# Epoch 92/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1022.3631 - val_loss: 800.4354
# Epoch 93/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1011.3796 - val_loss: 798.4728
# Epoch 94/100
# 3/3 [==============================] - 0s 18ms/step - loss: 999.2342 - val_loss: 797.4850
# Epoch 95/100
# 3/3 [==============================] - 0s 18ms/step - loss: 988.6820 - val_loss: 797.3351
# Epoch 96/100
# 3/3 [==============================] - 0s 15ms/step - loss: 980.1852 - val_loss: 797.9305
# Epoch 97/100
# 3/3 [==============================] - 0s 14ms/step - loss: 971.3304 - val_loss: 799.1085
# Epoch 98/100
# 3/3 [==============================] - 0s 15ms/step - loss: 962.8961 - val_loss: 800.6925
# Epoch 99/100
# 3/3 [==============================] - 0s 15ms/step - loss: 957.1725 - val_loss: 802.8141
# Epoch 100/100
# 3/3 [==============================] - 0s 15ms/step - loss: 951.8156 - val_loss: 805.3585
# 1/1 [==============================] - 0s 58ms/step

# %%
# Calculate the average scores over all folds
avg_mse = np.mean(mse_scores)
avg_rmse = np.mean(rmse_scores)
avg_mae = np.mean(mae_scores)
avg_r2 = np.mean(r2_scores)

# Print the results
print(f"Average Mean Squared Error: {avg_mse:.2f}%")
print(f"Average Root Mean Squared Error: {avg_rmse:.2f}%")
print(f"Average Mean Absolute Error: {avg_mae:.2f}%")
print(f"Average R-squared: {avg_r2:.2f}%")
# Out:
# Average Mean Squared Error: 963.13%
# Average Root Mean Squared Error: 31.90%
# Average Mean Absolute Error: 27.10%
# Average R-squared: -14.14%

# %%
# Find the most optimal production volume to minimize manufacturing cost
min_production_volume = supply_data['Production volumes'].min()
max_production_volume = 1000
step_size = 100

cheapest_cost = float('inf')
best_production_volume = None

for production_volume in range(min_production_volume, max_production_volume + 1, step_size):
    normalized_production_volume = scaler.transform(np.array([[production_volume]]))
    predicted_cost = model.predict(normalized_production_volume)

    if predicted_cost[0][0] < cheapest_cost:
        cheapest_cost = predicted_cost[0][0]
        best_production_volume = production_volume

print('Most optimal production volume to minimize manufacturing cost:', best_production_volume)
print('The cheapest manufacturing cost:', cheapest_cost)
# Out:
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# Most optimal production volume to minimize manufacturing cost: 104
# The cheapest manufacturing cost: 23.694384
