# %% [markdown]
# # Introduction
#
# In this supply chain analytics analysis, we encountered the challenge of working with a dataset consisting of 100 rows and 24 columns. During the Exploratory Data Analysis phase, we conducted quality control checks, assessed supply chain risks, performed Inventory Optimization Analysis using the Economic Order Quantity (EOQ) method, conducted customer segmentation analysis, and explored lead times optimization. However, in the modeling phase, we found that using LightGBM and RNN models was not suitable for this small dataset, resulting in unsatisfactory outcomes. Therefore, we recommend utilizing a larger dataset or considering alternatives such as linear regression, decision trees, or random forests to achieve better results in cost optimization and demand forecasting.In this supply chain analytics analysis, we encountered the challenge of working with a dataset consisting of 100 rows and 24 columns. During the Exploratory Data Analysis phase, we conducted quality control checks, assessed supply chain risks, performed Inventory Optimization Analysis using the Economic Order Quantity (EOQ) method, conducted customer segmentation analysis, and explored lead times optimization. However, in the modeling phase, we found that using LightGBM and RNN models was not suitable for this small dataset, resulting in unsatisfactory outcomes. Therefore, we recommend utilizing a larger dataset or considering alternatives such as linear regression, decision trees, or random forests to achieve better results in cost optimization and demand forecasting.

# %% [markdown]
# # Load data

# %%
# Disable warning

import warnings

warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=FutureWarning)

# %%
import pandas as pd

supply_data = pd.read_csv("/kaggle/input/supply-chain-analysis/supply_chain_data.csv")

# %%
supply_data.head()
# Out:
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.808006            55                      802
# 1     skincare  SKU1  14.843523            95                      736
# 2     haircare  SKU2  11.319683            34                        8
# 3     skincare  SKU3  61.163343            68                       83
# 4     skincare  SKU4   4.805496            26                      871
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58           7
# 1        7460.900065                Female            53          30
# 2        9577.749626               Unknown             1          10
# 3        7766.836426            Non-binary            23          13
# 4        2686.505152            Non-binary             5           3
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# 0                96  ...    Mumbai        29                 215
# 1                37  ...    Mumbai        23                 517
# 2                88  ...    Mumbai        12                 971
# 3                59  ...   Kolkata        24                 937
# 4                56  ...     Delhi         5                 414
#
#   Manufacturing lead time Manufacturing costs  Inspection results  \
# 0                      29           46.279879             Pending
# 1                      30           33.616769             Pending
# 2                      27           30.688019             Pending
# 3                      18           35.624741                Fail
# 4                       3           92.065161                Fail
#
#    Defect rates  Transportation modes   Routes       Costs
# 0      0.226410                  Road  Route B  187.752075
# 1      4.854068                  Road  Route B  503.065579
# 2      4.580593                   Air  Route C  141.920282
# 3      4.746649                  Rail  Route A  254.776159
# 4      3.145580                   Air  Route A  923.440632
#
# [5 rows x 24 columns]

# %%
supply_data.shape
# Out:
# (100, 24)

# %%
supply_data.columns
# Out:
# Index(['Product type', 'SKU', 'Price', 'Availability',
#        'Number of products sold', 'Revenue generated', 'Customer demographics',
#        'Stock levels', 'Lead times', 'Order quantities', 'Shipping times',
#        'Shipping carriers', 'Shipping costs', 'Supplier name', 'Location',
#        'Lead time', 'Production volumes', 'Manufacturing lead time',
#        'Manufacturing costs', 'Inspection results', 'Defect rates',
#        'Transportation modes', 'Routes', 'Costs'],
#       dtype='object')

# %% [markdown]
# **Feature explanation**
#
# - **Product Type**: The type of product associated with specific data in the supply chain.
# - **SKU (Stock Keeping Unit)**: Unique code used to identify a particular product.
# - **Price**: The price of the product or item in the supply chain.
# - **Availability**: Information about product availability.
# - **Number of Products Sold**: The number of products that have been sold in a certain time period.
# - **Revenue Generated**: Total revenue generated from product sales in a certain time period.
# - **Customer demographics**: Information about customer characteristics, such as age, gender, geographic location, etc.
# - **Stock Levels**: The number of products still available in stock at any given time.
# - **Lead Times**: The time required to order or receive products from suppliers.
# - **Order Quantities**: The number of products ordered in one order or shipment.
# - **Shipping Times**: The time required to ship products from the warehouse or distribution center to customers.
# - **Shipping Carriers**: Companies or services used to ship products to customers.
# - **Shipping Costs**: Costs associated with shipping products, including delivery fees and additional fees.
# - **Supplier Name**: Name of supplier or vendor who provides products or materials to the company.
# - **Location**: The physical location associated with the data in the supply chain, such as the location of a warehouse or distribution center.
# - **Lead Time**: The time required to obtain products or materials from a particular supplier.
# - **Production Volumes**: The number of products produced in a certain time period.
# - **Manufacturing Lead Time**: The time required to produce a product, from ordering materials until the product is ready.
# - **Manufacturing Costs**: Costs related to the production process, including raw material costs, labor, etc.
# - **Inspection Results**: Results of product or material quality inspection.
# - **Defect Rates**: The level of defects or defects in the products produced.
# - **Transportation Modes**: The transportation mode used to send products, such as land, sea or air.
# - **Routes**: Routes or paths used to send products from one point to another in the supply chain.
# - **Costs**: Costs related to various aspects of the supply chain, including transportation costs, production costs, and other costs.

# %%
supply_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Product type             100 non-null    object
#  1   SKU                      100 non-null    object
#  2   Price                    100 non-null    float64
#  3   Availability             100 non-null    int64
#  4   Number of products sold  100 non-null    int64
#  5   Revenue generated        100 non-null    float64
#  6   Customer demographics    100 non-null    object
#  7   Stock levels             100 non-null    int64
#  8   Lead times               100 non-null    int64
#  9   Order quantities         100 non-null    int64
#  10  Shipping times           100 non-null    int64
#  11  Shipping carriers        100 non-null    object
#  12  Shipping costs           100 non-null    float64
#  13  Supplier name            100 non-null    object
#  14  Location                 100 non-null    object
#  15  Lead time                100 non-null    int64
#  16  Production volumes       100 non-null    int64
#  17  Manufacturing lead time  100 non-null    int64
#  18  Manufacturing costs      100 non-null    float64
#  19  Inspection results       100 non-null    object
#  20  Defect rates             100 non-null    float64
#  21  Transportation modes     100 non-null    object
#  22  Routes                   100 non-null    object
#  23  Costs                    100 non-null    float64
# dtypes: float64(6), int64(9), object(9)
# memory usage: 18.9+ KB

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# ### Checking for missing values

# %%
# Check for missing values
missing_values = supply_data.isnull().sum()

# Display columns with missing values and the count of missing values
missing_values = missing_values[missing_values > 0]

if not missing_values.empty:
    print("Columns with missing values:")
    for column, count in missing_values.items():
        print(f"{column}: {count} missing values")
else:
    print("There are no columns with missing value")
# Out:
# There are no columns with missing value

# %% [markdown]
# ### Check for duplicate data

# %%
if supply_data.duplicated().any():
    print(f"There are as many as {supply_data.duplicated().sum()} duplicate data.")
else:
    print("There are no duplicate data.")
# Out:
# There are no duplicate data.

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Quality control check

# %%
import plotly.express as px

defect_rates_by_product = supply_data.groupby("Product type")['Defect rates'].mean().reset_index()

# Create a bar chart using Plotly
fig = px.bar(defect_rates_by_product, x='Product type', y='Defect rates', title='Defect Rates by Product Type')

# Customize the color scale for bars
color_scale = px.colors.qualitative.Set3  # You can choose a different color scale
fig.update_traces(marker_color=color_scale)

# Customize the appearance of the chart
fig.update_layout(
    xaxis_title="Product Type",
    yaxis_title="Mean Defect Rates",
    xaxis=dict(categoryorder='total descending'),
    yaxis=dict(title='Mean Defect Rates'),
    plot_bgcolor='white',
    title_x=0.5,
    showlegend=True  # Hide the legend
)

# Show the plot
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="61057089-ff98-403f-a819-6b19f5568643" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("61057089-ff98-403f-a819-6b19f5568643")) {                    Plotly.newPlot(                        "61057089-ff98-403f-a819-6b19f5568643",                        [{"alignmentgroup":"True","hovertemplate":"Product type=%{x}\u003cbr\u003eDefect rates=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":["rgb(141,211,199)","rgb(255,255,179)","rgb(190,186,218)","rgb(251,128,114)","rgb(128,177,211)","rgb(253,180,98)","rgb(179,222,105)","rgb(252,205,229)","rgb(217,217,217)","rgb(188,128,189)","rgb(204,235,197)","rgb(255,237,111)"],"pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["cosmetics","haircare","skincare"],"xaxis":"x","y":[1.9192869782813182,2.4831501929246245,2.334680781980237],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5 ...

# %% [markdown]
# ### Supply chain risk assessment

# %%
risk_data = supply_data[['SKU', 'Lead times', 'Stock levels']]
risk_data.head()
# Out:
#     SKU  Lead times  Stock levels
# 0  SKU0           7            58
# 1  SKU1          30            53
# 2  SKU2          10             1
# 3  SKU3          13            23
# 4  SKU4           3             5

# %%
risk_data['Risk score'] = risk_data['Lead times'] * (1-risk_data.loc[:,'Stock levels'])

# %%
# Sort the risk_data by 'Risk score' in descending order and select top 10 highest-risk data
risk_data = risk_data.sort_values(by='Risk score', ascending=False)[:10]

# Create a bar plot using Plotly Express
fig = px.bar(risk_data, x='SKU', y='Risk score', title='Top 10 Highest-Risk Data',
             labels={'Risk score': 'Risk Score', 'SKU': 'SKU'},
             text='Risk score')

# Customize the appearance of the plot
fig.update_traces(texttemplate='%{text:.2f}', textposition='outside')
fig.update_layout(xaxis_title='SKU', yaxis_title='Risk Score', title_x=0.5)

# Show the plot
fig.show()
# Out:
# <div>                            <div id="6929ef6c-8c5a-4bea-8e22-277f662a7375" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6929ef6c-8c5a-4bea-8e22-277f662a7375")) {                    Plotly.newPlot(                        "6929ef6c-8c5a-4bea-8e22-277f662a7375",                        [{"alignmentgroup":"True","hovertemplate":"SKU=%{x}\u003cbr\u003eRisk Score=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[8.0,0.0,0.0,-5.0,-12.0,-16.0,-28.0,-37.0,-40.0,-45.0],"textposition":"outside","x":["SKU68","SKU2","SKU34","SKU16","SKU4","SKU78","SKU87","SKU76","SKU8","SKU47"],"xaxis":"x","y":[8,0,0,-5,-12,-16,-28,-37,-40,-45],"yaxis":"y","type":"bar","texttemplate":"%{text:.2f}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay ...

# %% [markdown]
# ### Inventory Optimization Analysis with EOQ

# %%
# we assume for holding cost 0.2
holdingcost = 0.2

# %%
import numpy as np

def calculate_eoq(data):
    S = data['Costs']
    D = data['Number of products sold'] 
    H = data['Number of products sold'] * holdingcost
    EOQ = np.sqrt((2*S*D)/H)
    return round(EOQ)

# %%
supply_data['EOQ'] = calculate_eoq(supply_data)

# %%
comparison_columns = supply_data[['SKU', 'EOQ','Order quantities']]
comparison_columns.head()
# Out:
#     SKU   EOQ  Order quantities
# 0  SKU0  43.0                96
# 1  SKU1  71.0                37
# 2  SKU2  38.0                88
# 3  SKU3  50.0                59
# 4  SKU4  96.0                56

# %%
# Extracting the top 10 rows for comparison
top_10_comparison = comparison_columns.head(10)

# Creating a bar plot to compare EOQ and Order Quantities for the top 10 SKUs
fig = px.bar(top_10_comparison, x='SKU', y=['EOQ', 'Order quantities'], 
             title='Comparison of EOQ and Order Quantities for Top 10 SKUs')

fig.update_layout(
    title_x=0.5
)

# Displaying the plot
fig.show()
# Out:
# <div>                            <div id="a671b8b1-404e-4a03-b3cd-ca1e8edc1d10" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a671b8b1-404e-4a03-b3cd-ca1e8edc1d10")) {                    Plotly.newPlot(                        "a671b8b1-404e-4a03-b3cd-ca1e8edc1d10",                        [{"alignmentgroup":"True","hovertemplate":"variable=EOQ\u003cbr\u003eSKU=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"EOQ","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"EOQ","offsetgroup":"EOQ","orientation":"v","showlegend":true,"textposition":"auto","x":["SKU0","SKU1","SKU2","SKU3","SKU4","SKU5","SKU6","SKU7","SKU8","SKU9"],"xaxis":"x","y":[43.0,71.0,38.0,50.0,96.0,49.0,37.0,90.0,71.0,100.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"variable=Order quantities\u003cbr\u003eSKU=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Order quantities","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Order quantities","offsetgroup":"Order quantities","orientation":"v","showlegend":true,"textposition":"auto","x":["SKU0","SKU1","SKU2","SKU3","SKU4","SKU5","SKU6","SKU7","SKU8","SKU9"],"xaxis":"x","y":[96.0,37.0,88.0,59.0,56.0,66.0,58.0,11.0,15.0,83.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mes ...

# %% [markdown]
# ### Customer segmentation analysis

# %%
revenue_avg_by_demo_prod = supply_data.groupby(['Customer demographics', 'Product type'])['Revenue generated'].mean().reset_index()
revenue_sum_by_demo_prod = supply_data.groupby(['Customer demographics', 'Product type'])['Revenue generated'].sum().reset_index()

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# Create a palette of different colors for each product type
colors = px.colors.qualitative.Set3

# Create a subplot with 1 row and 2 columns
fig = make_subplots(rows=1, cols=2, subplot_titles=('Average Revenue', 'Total Revenue'))

# Plot for average revenue
for i, product_type in enumerate(revenue_avg_by_demo_prod['Product type'].unique()):
    subset = revenue_avg_by_demo_prod[revenue_avg_by_demo_prod['Product type'] == product_type]
    fig.add_trace(
        go.Bar(
            x=subset['Customer demographics'],
            y=subset['Revenue generated'],
            name=product_type,
            marker_color=colors[i]
        ),
        row=1, col=1
    )

# Plot for total revenue without legend
for i, product_type in enumerate(revenue_sum_by_demo_prod['Product type'].unique()):
    subset = revenue_sum_by_demo_prod[revenue_sum_by_demo_prod['Product type'] == product_type]
    fig.add_trace(
        go.Bar(
            x=subset['Customer demographics'],
            y=subset['Revenue generated'],
            showlegend=False,  # Hide legend for this subplot
            marker_color=colors[i]
        ),
        row=1, col=2
    )

# Beautify the subplot and show the legend for the first subplot
fig.update_layout(
    title='Revenue Analysis by Customer Demographics and Product Type',
    xaxis=dict(title='Customer Demographics'),
    yaxis=dict(title='Revenue'),
    xaxis2=dict(title='Customer Demographics'),
    yaxis2=dict(title='Revenue'),
    title_x=0.5,
    showlegend=True  # Show legend for the first subplot
)

# Show the subplot
fig.show()
# Out:
# <div>                            <div id="941381e5-331b-4778-8106-f2f0ad73428c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("941381e5-331b-4778-8106-f2f0ad73428c")) {                    Plotly.newPlot(                        "941381e5-331b-4778-8106-f2f0ad73428c",                        [{"marker":{"color":"rgb(141,211,199)"},"name":"cosmetics","x":["Female","Male","Non-binary","Unknown"],"y":[6954.854219685358,5347.7413743343,5247.096332116826,6335.182377815462],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(255,255,179)"},"name":"haircare","x":["Female","Male","Non-binary","Unknown"],"y":[6362.416641586338,5059.992730921369,5567.306726391122,4810.63219522254],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(190,186,218)"},"name":"skincare","x":["Female","Male","Non-binary","Unknown"],"y":[6095.470280123415,7806.214493320447,4650.8338885715775,6287.152695992038],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"rgb(141,211,199)"},"showlegend":false,"x":["Female","Male","Non-binary","Unknown"],"y":[69548.54219685358,21390.9654973372,26235.48166058413,44346.27664470823],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"rgb(255,255,179)"},"showlegend":false,"x":["Female","Male","Non-binary","Unknown"],"y":[12724.833283172677,50599.927309213694,38971.14708473785,72159.4829283381],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"rgb(190,186,218)"},"showlegend":false,"x":["Female","Male","Non-binary","Unknown"],"y":[79241.1136416044,54643.50145324313,51159.17277428735,56584.374263928345],"type":"bar","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"color ...

# %% [markdown]
# ### Lead times optimization analysis

# %%
avg_lead_times_transport = supply_data.groupby(['Transportation modes'])['Lead times'].mean().reset_index()

fig = px.bar(avg_lead_times_transport, x='Transportation modes', y='Lead times',
             labels={'Transportation modes': 'Transportation Mode', 'Lead times': 'Average Lead Time'},
             title='Average Lead Times by Transportation Mode')

# Customize the color scale for bars
color_scale = px.colors.qualitative.Set3  # You can choose a different color scale
fig.update_traces(marker_color=color_scale)

# Customize the layout for beautification
fig.update_layout(
    title=dict(text='Average Lead Times by Transportation Mode', x=0.5),
    xaxis_title='Transportation Mode',
    yaxis_title='Average Lead Time',
    xaxis_tickangle=-45,  # Rotate x-axis labels for better readability
    font=dict(family="Arial", size=14),
    showlegend=False  # Remove legend
)

# Show the plot
fig.show()
# Out:
# <div>                            <div id="3d71dff4-35b1-4a2a-823a-35973619b6c5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3d71dff4-35b1-4a2a-823a-35973619b6c5")) {                    Plotly.newPlot(                        "3d71dff4-35b1-4a2a-823a-35973619b6c5",                        [{"alignmentgroup":"True","hovertemplate":"Transportation Mode=%{x}\u003cbr\u003eAverage Lead Time=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":["rgb(141,211,199)","rgb(255,255,179)","rgb(190,186,218)","rgb(251,128,114)","rgb(128,177,211)","rgb(253,180,98)","rgb(179,222,105)","rgb(252,205,229)","rgb(217,217,217)","rgb(188,128,189)","rgb(204,235,197)","rgb(255,237,111)"],"pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Air","Rail","Road","Sea"],"xaxis":"x","y":[18.26923076923077,14.892857142857142,17.137931034482758,12.176470588235293],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"er ...

# %%
best_transportation_mode = avg_lead_times_transport.loc[avg_lead_times_transport['Lead times'].idxmin()]
best_transportation_mode
# Out:
# Transportation modes          Sea
# Lead times              12.176471
# Name: 3, dtype: object

# %%
best_transportation_data = supply_data[supply_data['Transportation modes']==best_transportation_mode['Transportation modes']]
best_transportation_data.head()
# Out:
#    Product type    SKU      Price  Availability  Number of products sold  \
# 6      skincare   SKU6   4.078333            48                       65
# 8     cosmetics   SKU8  68.717597            78                      150
# 15     skincare  SKU15  36.989245            94                      469
# 18     haircare  SKU18  36.443628            23                      620
# 27    cosmetics  SKU27  92.557361            42                      352
#
#     Revenue generated Customer demographics  Stock levels  Lead times  \
# 6         7823.476560                  Male            11          15
# 8         7517.363211                Female             5          10
# 15        5442.086785            Non-binary             9           8
# 18        9364.673505               Unknown            10          10
# 27        2686.457224               Unknown            47           9
#
#     Order quantities  ...  Lead time Production volumes  \
# 6                 58  ...         14                314
# 8                 15  ...         13                769
# 15                69  ...         14                580
# 18                46  ...         18                374
# 27                62  ...         25                291
#
#     Manufacturing lead time Manufacturing costs Inspection results  \
# 6                        24            1.085069            Pending
# 8                         8           11.423027            Pending
# 15                        7           97.121282               Pass
# 18                       17           27.107981            Pending
# 27                        4           10.528245               Fail
#
#     Defect rates  Transportation modes   Routes       Costs   EOQ
# 6       1.000911                   Sea  Route A  134.369097  37.0
# 8       2.709863                   Sea  Route B  505.557134  71.0
# 15      2.264406                   Sea  Route B  127.861800  36.0
# 18      2.231939                   Sea  Route A  593.480259  77.0
# 27      2.864668                   Sea  Route B  762.459182  87.0
#
# [5 rows x 25 columns]

# %%
import plotly.express as px

avg_lead_times_route = supply_data.groupby(['Routes'])['Lead times'].mean().reset_index()

# Assuming you have the avg_lead_times_route DataFrame already defined
fig = px.bar(avg_lead_times_route, x='Routes', y='Lead times',
             labels={'Routes': 'Route', 'Lead times': 'Average Lead Time'},
             title='Average Lead Times by Route')

# Customize the color scale for bars
color_scale = px.colors.qualitative.Set3  # You can choose a different color scale
fig.update_traces(marker_color=color_scale)

# Customize the layout for beautification
fig.update_layout(
    title=dict(text='Average Lead Times by Route', x=0.5),
    xaxis_title='Route',
    yaxis_title='Average Lead Time',
    xaxis_tickangle=-45,  # Rotate x-axis labels for better readability
    font=dict(family="Arial", size=14),
    showlegend=False  # Remove legend
)

# Show the plot
fig.show()
# Out:
# <div>                            <div id="a731c9d5-cb4f-4b08-996c-b4d29f450895" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a731c9d5-cb4f-4b08-996c-b4d29f450895")) {                    Plotly.newPlot(                        "a731c9d5-cb4f-4b08-996c-b4d29f450895",                        [{"alignmentgroup":"True","hovertemplate":"Route=%{x}\u003cbr\u003eAverage Lead Time=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":["rgb(141,211,199)","rgb(255,255,179)","rgb(190,186,218)","rgb(251,128,114)","rgb(128,177,211)","rgb(253,180,98)","rgb(179,222,105)","rgb(252,205,229)","rgb(217,217,217)","rgb(188,128,189)","rgb(204,235,197)","rgb(255,237,111)"],"pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Route A","Route B","Route C"],"xaxis":"x","y":[14.69767441860465,17.216216216216218,16.35],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"col ...

# %%
best_route = avg_lead_times_route.loc[avg_lead_times_route['Lead times'].idxmin()]
best_route
# Out:
# Routes          Route A
# Lead times    14.697674
# Name: 0, dtype: object

# %%
best_route_data = supply_data[supply_data['Routes']==best_route['Routes']]
best_route_data.head()
# Out:
#    Product type    SKU      Price  Availability  Number of products sold  \
# 3      skincare   SKU3  61.163343            68                       83
# 4      skincare   SKU4   4.805496            26                      871
# 5      haircare   SKU5   1.699976            87                      147
# 6      skincare   SKU6   4.078333            48                       65
# 11     skincare  SKU11  90.635460            95                      960
#
#     Revenue generated Customer demographics  Stock levels  Lead times  \
# 3         7766.836426            Non-binary            23          13
# 4         2686.505152            Non-binary             5           3
# 5         2828.348746            Non-binary            90          27
# 6         7823.476560                  Male            11          15
# 11        6099.944116                Female            46          23
#
#     Order quantities  ...  Lead time Production volumes  \
# 3                 59  ...         24                937
# 4                 56  ...          5                414
# 5                 66  ...         10                104
# 6                 58  ...         14                314
# 11                60  ...         28                362
#
#     Manufacturing lead time Manufacturing costs Inspection results  \
# 3                        18           35.624741               Fail
# 4                         3           92.065161               Fail
# 5                        17           56.766476               Fail
# 6                        24            1.085069            Pending
# 11                       11           27.592363            Pending
#
#     Defect rates  Transportation modes   Routes       Costs   EOQ
# 3       4.746649                  Rail  Route A  254.776159  50.0
# 4       3.145580                   Air  Route A  923.440632  96.0
# 5       2.779194                  Road  Route A  235.461237  49.0
# 6       1.000911                   Sea  Route A  134.369097  37.0
# 11      0.021170                   Air  Route A  126.723033  36.0
#
# [5 rows x 25 columns]

# %% [markdown]
# # Modelling

# %% [markdown]
# ### Forecasting demand

# %%
X = supply_data.loc[:,['Price', 'Availability', 'Stock levels', 'Lead times', 'Order quantities']]
y = supply_data.loc[:,'Number of products sold']

# %%
# Define the number of folds for cross-validation
num_folds = 10

# %%
# Initialize lists to store evaluation metrics
mse_scores = []
rmse_scores = []
mae_scores = []
r2_scores = []

# %%
from sklearn.model_selection import KFold

# Create a KFold object
kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)

# %%
# Define the parameters for LightGBM
params = {
    'objective': 'regression',
    'metric': 'mean_squared_error',
    'boosting_type': 'gbdt',
    'num_leaves': 31,
    'learning_rate': 0.05,
    'feature_fraction': 0.9
}

# %%
import lightgbm as lgb
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Create LightGBM datasets for training and testing
    train_data = lgb.Dataset(X_train, label=y_train)
    test_data = lgb.Dataset(X_test, label=y_test, reference=train_data)
    
    # Add early stopping
    num_round = 100  # Increase the number of boosting rounds
    early_stopping_rounds = 5  # Set the number of rounds to wait for early stopping

    # Train the model with early stopping
    bst = lgb.train(
        params,
        train_data,
        num_round,
        valid_sets=[test_data],
        early_stopping_rounds=early_stopping_rounds,
        verbose_eval=10
    )
    
    # Make predictions on the test set
    y_pred = bst.predict(X_test, num_iteration=bst.best_iteration)

    # Calculate metrics
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    # Calculate the target range
    target_range = np.max(y_test) - np.min(y_test)

    # Calculate metrics as percentages
    percentage_mse = (mse / target_range) * 100
    percentage_rmse = (rmse / target_range) * 100
    percentage_mae = (mae / target_range) * 100
    percentage_r2 = (r2 * 100)

    # Append the scores to the respective lists
    mse_scores.append(percentage_mse)
    rmse_scores.append(percentage_rmse)
    mae_scores.append(percentage_mae)
    r2_scores.append(percentage_r2)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002892 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 135
# [LightGBM] [Info] Number of data points in the train set: 90, number of used features: 5
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 449.877778
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 5 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [1]	valid_0's l2: 152909
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000444 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 137
# [LightGBM] [Info] Number of data points in the train set: 90, number of used features: 5
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 465.177778
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 5 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [3]	valid_0's l2: 42338.7
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000353 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 134
# [LightGBM] [Info] Number of data points in the train set: 90, number of used features: 5
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 449.533333
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 5 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	valid_0's l2: 75638.8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [14]	valid_0's l2: 75013.7
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000369 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 134
# [LightGBM] [Info] Number of data points in the train set: 90, number of used features: 5
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 462.877778
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 5 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [1]	valid_0's l2: 95404.3
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000493 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 133
# [LightGBM] [Info] Number of data points in the train set: 90, number of used features: 5
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 470.288889
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 5 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [1]	valid_0's l2: 58352.6
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000327 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 136
# [LightGBM] [Info] Number of data points in the train set: 90, number of used features: 5
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 473.155556
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 5 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [1]	valid_0's l2: 137452
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000542 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 136
# [LightGBM] [Info] Number of data points in the train set: 90, number of used features: 5
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 464.577778
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 5 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [4]	valid_0's l2: 76462.3
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000352 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 135
# [LightGBM] [Info] Number of data points in the train set: 90, number of used features: 5
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 454.688889
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 5 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [1]	valid_0's l2: 122894
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000375 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 136
# [LightGBM] [Info] Number of data points in the train set: 90, number of used features: 5
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 459.822222
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 5 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [2]	valid_0's l2: 94322.5
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000542 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 135
# [LightGBM] [Info] Number of data points in the train set: 90, number of used features: 5
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 459.900000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 5 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	valid_0's l2: 62553.3
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [20]	valid_0's l2: 59845.7
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [30]	valid_0's l2: 57732.8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [40]	valid_0's l2: 56213.2
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [50]	valid_0's l2: 55133.7
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [60]	valid_0's l2: 55135.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [57]	valid_0's l2: 54910.1

# %%
# Calculate the average scores over all folds
avg_mse = np.mean(mse_scores)
avg_rmse = np.mean(rmse_scores)
avg_mae = np.mean(mae_scores)
avg_r2 = np.mean(r2_scores)

# Print the results
print(f"Average Mean Squared Error: {avg_mse:.2f}%")
print(f"Average Root Mean Squared Error: {avg_rmse:.2f}%")
print(f"Average Mean Absolute Error: {avg_mae:.2f}%")
print(f"Average R-squared: {avg_r2:.2f}%")
# Out:
# Average Mean Squared Error: 10450.61%
# Average Root Mean Squared Error: 34.70%
# Average Mean Absolute Error: 31.02%
# Average R-squared: -4.64%

# %% [markdown]
# ### Cost optimization

# %%
# Extract the features (X) and target (y)
X = supply_data.loc[:, 'Production volumes'].values.reshape(-1, 1)
y = supply_data.loc[:, 'Manufacturing costs'].values

# %%
# Define the number of folds for cross-validation
num_folds = 5

# %%
# Initialize lists to store evaluation metrics
mse_scores = []
rmse_scores = []
mae_scores = []
r2_scores = []

# %%
from sklearn.preprocessing import MinMaxScaler

# Initialize and fit the scaler to the data
scaler = MinMaxScaler()
scaler.fit(X)
# Out:
# MinMaxScaler()

# %%
# Create a KFold object
kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # Scale the data
    X_train_scaled = scaler.transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    # Define and compile the neural network model
    model = tf.keras.Sequential([
        Dense(64, activation='relu', input_dim=1),
        Dense(32, activation='relu'),
        Dense(1)
    ])

    model.compile(optimizer='adam', loss='mean_squared_error')
    
    # Define Early Stopping callback
    early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

    # Define Model Checkpoint callback to save the best model
    model_checkpoint = ModelCheckpoint('/kaggle/working/best_model.h5', save_best_only=True, save_weights_only=True, monitor='val_loss', mode='min')

    # Train the model on the training data with callbacks
    history = model.fit(X_train_scaled,
                        y_train, epochs=100,
                        batch_size=32,
                        validation_data=(X_test_scaled, y_test),
                        callbacks=[early_stopping, model_checkpoint])

    # Load the best model weights from the saved checkpoint
    model.load_weights('/kaggle/working/best_model.h5')
    
    # Make predictions on the test set
    y_pred = model.predict(X_test_scaled)
    
    # Calculate metrics
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    mae = np.mean(np.abs(y_test - y_pred))
    r2 = r2_score(y_test, y_pred)

    # Calculate metrics as percentages
    target_range = np.max(y_test) - np.min(y_test)
    percentage_mse = (mse / target_range) * 100
    percentage_rmse = (rmse / target_range) * 100
    percentage_mae = (mae / target_range) * 100
    percentage_r2 = (r2 * 100)

    # Append the scores to the respective lists
    mse_scores.append(percentage_mse)
    rmse_scores.append(percentage_rmse)
    mae_scores.append(percentage_mae)
    r2_scores.append(percentage_r2)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 1s 127ms/step - loss: 2896.7642 - val_loss: 3691.9077
# Epoch 2/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2890.3384 - val_loss: 3684.1335
# Epoch 3/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2883.4121 - val_loss: 3675.6882
# Epoch 4/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2876.3440 - val_loss: 3666.6804
# Epoch 5/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2868.4082 - val_loss: 3657.0437
# Epoch 6/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2860.2524 - val_loss: 3646.8965
# Epoch 7/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2851.8157 - val_loss: 3636.1392
# Epoch 8/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2842.7664 - val_loss: 3624.7886
# Epoch 9/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2832.6519 - val_loss: 3612.8250
# Epoch 10/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2822.1326 - val_loss: 3600.1743
# Epoch 11/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2811.6118 - val_loss: 3586.6836
# Epoch 12/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2799.8503 - val_loss: 3572.4219
# Epoch 13/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2788.3364 - val_loss: 3557.2825
# Epoch 14/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2775.0757 - val_loss: 3541.6147
# Epoch 15/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2761.6792 - val_loss: 3524.9419
# Epoch 16/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2747.7346 - val_loss: 3507.1418
# Epoch 17/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2732.3530 - val_loss: 3488.3625
# Epoch 18/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2716.0952 - val_loss: 3468.3328
# Epoch 19/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2698.8994 - val_loss: 3446.9211
# Epoch 20/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2680.6206 - val_loss: 3424.1023
# Epoch 21/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2662.3984 - val_loss: 3399.7852
# Epoch 22/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2640.9075 - val_loss: 3374.4199
# Epoch 23/100
# 3/3 [==============================] - 0s 28ms/step - loss: 2619.1714 - val_loss: 3347.4663
# Epoch 24/100
# 3/3 [==============================] - 0s 28ms/step - loss: 2596.8481 - val_loss: 3318.7422
# Epoch 25/100
# 3/3 [==============================] - 0s 28ms/step - loss: 2571.7661 - val_loss: 3288.7134
# Epoch 26/100
# 3/3 [==============================] - 0s 28ms/step - loss: 2546.8403 - val_loss: 3256.9019
# Epoch 27/100
# 3/3 [==============================] - 0s 28ms/step - loss: 2519.9590 - val_loss: 3223.4121
# Epoch 28/100
# 3/3 [==============================] - 0s 28ms/step - loss: 2491.4565 - val_loss: 3188.2129
# Epoch 29/100
# 3/3 [==============================] - 0s 28ms/step - loss: 2462.6973 - val_loss: 3151.0542
# Epoch 30/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2431.4861 - val_loss: 3112.3223
# Epoch 31/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2398.7544 - val_loss: 3071.9878
# Epoch 32/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2366.0698 - val_loss: 3029.9124
# Epoch 33/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2330.7485 - val_loss: 2986.5566
# Epoch 34/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2294.9871 - val_loss: 2941.6594
# Epoch 35/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2256.5652 - val_loss: 2895.3950
# Epoch 36/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2220.4709 - val_loss: 2846.8071
# Epoch 37/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2179.6174 - val_loss: 2797.2349
# Epoch 38/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2139.7805 - val_loss: 2746.0828
# Epoch 39/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2098.0669 - val_loss: 2693.8218
# Epoch 40/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2054.3972 - val_loss: 2640.5361
# Epoch 41/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2010.5680 - val_loss: 2585.6248
# Epoch 42/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1968.5000 - val_loss: 2528.6489
# Epoch 43/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1925.0551 - val_loss: 2470.7483
# Epoch 44/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1875.7156 - val_loss: 2413.3762
# Epoch 45/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1829.8896 - val_loss: 2354.7603
# Epoch 46/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1784.2053 - val_loss: 2295.1863
# Epoch 47/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1738.5286 - val_loss: 2235.1113
# Epoch 48/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1693.3268 - val_loss: 2174.7410
# Epoch 49/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1645.6414 - val_loss: 2114.7500
# Epoch 50/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1600.7574 - val_loss: 2054.8020
# Epoch 51/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1554.3059 - val_loss: 1995.9111
# Epoch 52/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1511.1150 - val_loss: 1936.9430
# Epoch 53/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1465.6881 - val_loss: 1878.9180
# Epoch 54/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1424.1285 - val_loss: 1820.8383
# Epoch 55/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1382.4126 - val_loss: 1763.8450
# Epoch 56/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1338.4099 - val_loss: 1708.9753
# Epoch 57/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1299.9994 - val_loss: 1654.7937
# Epoch 58/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1266.3639 - val_loss: 1601.6399
# Epoch 59/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1228.4133 - val_loss: 1552.1848
# Epoch 60/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1192.5809 - val_loss: 1505.1625
# Epoch 61/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1164.8197 - val_loss: 1458.9072
# Epoch 62/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1132.2949 - val_loss: 1416.6530
# Epoch 63/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1107.3732 - val_loss: 1375.2109
# Epoch 64/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1082.7717 - val_loss: 1335.9669
# Epoch 65/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1058.7778 - val_loss: 1299.2168
# Epoch 66/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1039.2170 - val_loss: 1265.1106
# Epoch 67/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1017.8402 - val_loss: 1234.5992
# Epoch 68/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1001.3995 - val_loss: 1205.5995
# Epoch 69/100
# 3/3 [==============================] - 0s 20ms/step - loss: 985.8167 - val_loss: 1178.4846
# Epoch 70/100
# 3/3 [==============================] - 0s 19ms/step - loss: 972.8890 - val_loss: 1153.2771
# Epoch 71/100
# 3/3 [==============================] - 0s 20ms/step - loss: 962.3371 - val_loss: 1130.5706
# Epoch 72/100
# 3/3 [==============================] - 0s 21ms/step - loss: 951.3138 - val_loss: 1110.7474
# Epoch 73/100
# 3/3 [==============================] - 0s 21ms/step - loss: 941.4855 - val_loss: 1092.7318
# Epoch 74/100
# 3/3 [==============================] - 0s 20ms/step - loss: 935.9427 - val_loss: 1075.4167
# Epoch 75/100
# 3/3 [==============================] - 0s 20ms/step - loss: 930.2342 - val_loss: 1060.1627
# Epoch 76/100
# 3/3 [==============================] - 0s 20ms/step - loss: 924.3419 - val_loss: 1047.2977
# Epoch 77/100
# 3/3 [==============================] - 0s 19ms/step - loss: 920.3903 - val_loss: 1035.8864
# Epoch 78/100
# 3/3 [==============================] - 0s 19ms/step - loss: 917.0758 - val_loss: 1026.0131
# Epoch 79/100
# 3/3 [==============================] - 0s 20ms/step - loss: 914.2176 - val_loss: 1017.2025
# Epoch 80/100
# 3/3 [==============================] - 0s 21ms/step - loss: 911.4912 - val_loss: 1009.7570
# Epoch 81/100
# 3/3 [==============================] - 0s 20ms/step - loss: 910.4554 - val_loss: 1002.4885
# Epoch 82/100
# 3/3 [==============================] - 0s 22ms/step - loss: 908.5822 - val_loss: 996.9133
# Epoch 83/100
# 3/3 [==============================] - 0s 22ms/step - loss: 907.6254 - val_loss: 991.8026
# Epoch 84/100
# 3/3 [==============================] - 0s 22ms/step - loss: 906.7462 - val_loss: 987.5202
# Epoch 85/100
# 3/3 [==============================] - 0s 21ms/step - loss: 906.0296 - val_loss: 983.7092
# Epoch 86/100
# 3/3 [==============================] - 0s 21ms/step - loss: 905.2848 - val_loss: 980.4022
# Epoch 87/100
# 3/3 [==============================] - 0s 20ms/step - loss: 904.9258 - val_loss: 977.0741
# Epoch 88/100
# 3/3 [==============================] - 0s 20ms/step - loss: 904.5194 - val_loss: 974.6621
# Epoch 89/100
# 3/3 [==============================] - 0s 21ms/step - loss: 904.0459 - val_loss: 973.3099
# Epoch 90/100
# 3/3 [==============================] - 0s 21ms/step - loss: 903.5486 - val_loss: 972.8949
# Epoch 91/100
# 3/3 [==============================] - 0s 22ms/step - loss: 902.9941 - val_loss: 971.4969
# Epoch 92/100
# 3/3 [==============================] - 0s 21ms/step - loss: 902.8717 - val_loss: 969.1686
# Epoch 93/100
# 3/3 [==============================] - 0s 21ms/step - loss: 902.1705 - val_loss: 967.4740
# Epoch 94/100
# 3/3 [==============================] - 0s 20ms/step - loss: 901.7734 - val_loss: 965.8040
# Epoch 95/100
# 3/3 [==============================] - 0s 20ms/step - loss: 901.2433 - val_loss: 964.6193
# Epoch 96/100
# 3/3 [==============================] - 0s 21ms/step - loss: 900.9725 - val_loss: 963.5394
# Epoch 97/100
# 3/3 [==============================] - 0s 22ms/step - loss: 900.6670 - val_loss: 961.5983
# Epoch 98/100
# 3/3 [==============================] - 0s 22ms/step - loss: 900.4479 - val_loss: 959.3540
# Epoch 99/100
# 3/3 [==============================] - 0s 20ms/step - loss: 899.9242 - val_loss: 958.5549
# Epoch 100/100
# 3/3 [==============================] - 0s 21ms/step - loss: 899.5625 - val_loss: 957.9889
# 1/1 [==============================] - 0s 110ms/step
# Epoch 1/100
# 3/3 [==============================] - 1s 91ms/step - loss: 2966.0945 - val_loss: 3455.6511
# Epoch 2/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2959.4194 - val_loss: 3449.4575
# Epoch 3/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2953.4600 - val_loss: 3443.9934
# Epoch 4/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2948.1531 - val_loss: 3438.9321
# Epoch 5/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2943.3796 - val_loss: 3434.1765
# Epoch 6/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2938.9438 - val_loss: 3429.4226
# Epoch 7/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2934.3628 - val_loss: 3424.6699
# Epoch 8/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2929.8091 - val_loss: 3419.6323
# Epoch 9/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2924.8582 - val_loss: 3414.2310
# Epoch 10/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2919.6274 - val_loss: 3408.4114
# Epoch 11/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2913.7253 - val_loss: 3402.1731
# Epoch 12/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2907.9915 - val_loss: 3395.4036
# Epoch 13/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2901.1589 - val_loss: 3388.2083
# Epoch 14/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2894.1504 - val_loss: 3380.3979
# Epoch 15/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2886.9370 - val_loss: 3371.9185
# Epoch 16/100
# 3/3 [==============================] - 0s 24ms/step - loss: 2878.7222 - val_loss: 3362.8464
# Epoch 17/100
# 3/3 [==============================] - 0s 32ms/step - loss: 2869.8743 - val_loss: 3353.1394
# Epoch 18/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2860.7065 - val_loss: 3342.7117
# Epoch 19/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2850.1609 - val_loss: 3331.5969
# Epoch 20/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2840.0566 - val_loss: 3319.4863
# Epoch 21/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2828.3284 - val_loss: 3306.6118
# Epoch 22/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2815.9856 - val_loss: 3292.8230
# Epoch 23/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2802.9407 - val_loss: 3278.0586
# Epoch 24/100
# 3/3 [==============================] - 0s 23ms/step - loss: 2788.8599 - val_loss: 3262.3499
# Epoch 25/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2773.2478 - val_loss: 3245.7070
# Epoch 26/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2757.7688 - val_loss: 3227.8491
# Epoch 27/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2740.3862 - val_loss: 3208.9526
# Epoch 28/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2722.7964 - val_loss: 3188.6936
# Epoch 29/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2703.9260 - val_loss: 3167.2476
# Epoch 30/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2683.1338 - val_loss: 3144.7490
# Epoch 31/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2662.8516 - val_loss: 3120.8850
# Epoch 32/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2639.1299 - val_loss: 3096.1245
# Epoch 33/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2616.4795 - val_loss: 3069.8218
# Epoch 34/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2591.4314 - val_loss: 3042.3435
# Epoch 35/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2565.1614 - val_loss: 3013.5771
# Epoch 36/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2537.4075 - val_loss: 2983.4902
# Epoch 37/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2509.1699 - val_loss: 2951.6865
# Epoch 38/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2479.8662 - val_loss: 2918.3804
# Epoch 39/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2448.7812 - val_loss: 2883.9614
# Epoch 40/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2416.6626 - val_loss: 2848.4199
# Epoch 41/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2383.9709 - val_loss: 2811.5964
# Epoch 42/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2348.7454 - val_loss: 2773.5996
# Epoch 43/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2313.3364 - val_loss: 2734.1160
# Epoch 44/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2277.4233 - val_loss: 2693.2236
# Epoch 45/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2241.2114 - val_loss: 2651.1272
# Epoch 46/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2200.9360 - val_loss: 2608.6599
# Epoch 47/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2163.4968 - val_loss: 2565.0181
# Epoch 48/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2122.2388 - val_loss: 2521.0713
# Epoch 49/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2081.3042 - val_loss: 2476.0200
# Epoch 50/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2040.8777 - val_loss: 2429.6448
# Epoch 51/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1998.8503 - val_loss: 2382.4702
# Epoch 52/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1954.8684 - val_loss: 2334.9451
# Epoch 53/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1915.0442 - val_loss: 2286.5332
# Epoch 54/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1869.9076 - val_loss: 2238.4597
# Epoch 55/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1827.8064 - val_loss: 2190.0476
# Epoch 56/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1784.7281 - val_loss: 2141.8667
# Epoch 57/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1740.4254 - val_loss: 2094.0742
# Epoch 58/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1698.2646 - val_loss: 2045.8170
# Epoch 59/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1655.1995 - val_loss: 1997.7351
# Epoch 60/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1610.9707 - val_loss: 1949.9629
# Epoch 61/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1570.2488 - val_loss: 1901.7865
# Epoch 62/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1530.1895 - val_loss: 1853.7766
# Epoch 63/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1488.4656 - val_loss: 1806.7166
# Epoch 64/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1448.8380 - val_loss: 1760.6705
# Epoch 65/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1406.2627 - val_loss: 1716.2937
# Epoch 66/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1369.8914 - val_loss: 1671.9840
# Epoch 67/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1334.0764 - val_loss: 1628.7861
# Epoch 68/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1297.5771 - val_loss: 1587.8685
# Epoch 69/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1264.0176 - val_loss: 1548.8248
# Epoch 70/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1231.6523 - val_loss: 1511.2190
# Epoch 71/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1200.2552 - val_loss: 1474.8616
# Epoch 72/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1171.0979 - val_loss: 1439.7336
# Epoch 73/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1144.3281 - val_loss: 1405.4993
# Epoch 74/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1118.0426 - val_loss: 1372.9402
# Epoch 75/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1091.4512 - val_loss: 1342.0422
# Epoch 76/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1068.5248 - val_loss: 1312.5497
# Epoch 77/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1045.1123 - val_loss: 1285.4470
# Epoch 78/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1027.8679 - val_loss: 1259.5725
# Epoch 79/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1007.9576 - val_loss: 1235.9803
# Epoch 80/100
# 3/3 [==============================] - 0s 21ms/step - loss: 990.9718 - val_loss: 1214.3049
# Epoch 81/100
# 3/3 [==============================] - 0s 20ms/step - loss: 977.6164 - val_loss: 1194.5259
# Epoch 82/100
# 3/3 [==============================] - 0s 20ms/step - loss: 964.8983 - val_loss: 1176.8787
# Epoch 83/100
# 3/3 [==============================] - 0s 20ms/step - loss: 952.3866 - val_loss: 1161.1449
# Epoch 84/100
# 3/3 [==============================] - 0s 21ms/step - loss: 942.5835 - val_loss: 1146.2109
# Epoch 85/100
# 3/3 [==============================] - 0s 20ms/step - loss: 933.5814 - val_loss: 1132.3606
# Epoch 86/100
# 3/3 [==============================] - 0s 22ms/step - loss: 925.9218 - val_loss: 1119.5847
# Epoch 87/100
# 3/3 [==============================] - 0s 22ms/step - loss: 918.5531 - val_loss: 1108.1936
# Epoch 88/100
# 3/3 [==============================] - 0s 20ms/step - loss: 914.1595 - val_loss: 1097.7783
# Epoch 89/100
# 3/3 [==============================] - 0s 24ms/step - loss: 907.8823 - val_loss: 1089.0951
# Epoch 90/100
# 3/3 [==============================] - 0s 24ms/step - loss: 903.9260 - val_loss: 1081.4032
# Epoch 91/100
# 3/3 [==============================] - 0s 20ms/step - loss: 900.7796 - val_loss: 1074.3851
# Epoch 92/100
# 3/3 [==============================] - 0s 20ms/step - loss: 896.7430 - val_loss: 1068.5164
# Epoch 93/100
# 3/3 [==============================] - 0s 20ms/step - loss: 894.9512 - val_loss: 1063.0286
# Epoch 94/100
# 3/3 [==============================] - 0s 20ms/step - loss: 892.4696 - val_loss: 1058.3202
# Epoch 95/100
# 3/3 [==============================] - 0s 22ms/step - loss: 890.0912 - val_loss: 1054.1959
# Epoch 96/100
# 3/3 [==============================] - 0s 23ms/step - loss: 890.3495 - val_loss: 1049.5927
# Epoch 97/100
# 3/3 [==============================] - 0s 21ms/step - loss: 887.9303 - val_loss: 1046.0369
# Epoch 98/100
# 3/3 [==============================] - 0s 21ms/step - loss: 887.2826 - val_loss: 1042.7576
# Epoch 99/100
# 3/3 [==============================] - 0s 22ms/step - loss: 885.9891 - val_loss: 1040.1067
# Epoch 100/100
# 3/3 [==============================] - 0s 20ms/step - loss: 885.5446 - val_loss: 1037.5677
# 1/1 [==============================] - 0s 63ms/step
# Epoch 1/100
# 3/3 [==============================] - 1s 102ms/step - loss: 3190.2427 - val_loss: 2592.5938
# Epoch 2/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3184.3198 - val_loss: 2587.9282
# Epoch 3/100
# 3/3 [==============================] - 0s 20ms/step - loss: 3178.9321 - val_loss: 2583.9399
# Epoch 4/100
# 3/3 [==============================] - 0s 21ms/step - loss: 3174.3706 - val_loss: 2580.2815
# Epoch 5/100
# 3/3 [==============================] - 0s 20ms/step - loss: 3169.9954 - val_loss: 2576.6848
# Epoch 6/100
# 3/3 [==============================] - 0s 21ms/step - loss: 3165.5901 - val_loss: 2573.2615
# Epoch 7/100
# 3/3 [==============================] - 0s 21ms/step - loss: 3161.4844 - val_loss: 2570.0566
# Epoch 8/100
# 3/3 [==============================] - 0s 20ms/step - loss: 3157.7727 - val_loss: 2567.0347
# Epoch 9/100
# 3/3 [==============================] - 0s 21ms/step - loss: 3154.1140 - val_loss: 2563.9233
# Epoch 10/100
# 3/3 [==============================] - 0s 22ms/step - loss: 3150.3372 - val_loss: 2560.6050
# Epoch 11/100
# 3/3 [==============================] - 0s 23ms/step - loss: 3146.2319 - val_loss: 2557.0764
# Epoch 12/100
# 3/3 [==============================] - 0s 22ms/step - loss: 3141.8884 - val_loss: 2553.3096
# Epoch 13/100
# 3/3 [==============================] - 0s 22ms/step - loss: 3137.2676 - val_loss: 2549.3276
# Epoch 14/100
# 3/3 [==============================] - 0s 20ms/step - loss: 3132.2966 - val_loss: 2545.0359
# Epoch 15/100
# 3/3 [==============================] - 0s 21ms/step - loss: 3127.1753 - val_loss: 2540.4578
# Epoch 16/100
# 3/3 [==============================] - 0s 21ms/step - loss: 3121.6116 - val_loss: 2535.5745
# Epoch 17/100
# 3/3 [==============================] - 0s 21ms/step - loss: 3115.3196 - val_loss: 2530.3547
# Epoch 18/100
# 3/3 [==============================] - 0s 20ms/step - loss: 3109.0220 - val_loss: 2524.7271
# Epoch 19/100
# 3/3 [==============================] - 0s 21ms/step - loss: 3101.7576 - val_loss: 2518.7075
# Epoch 20/100
# 3/3 [==============================] - 0s 20ms/step - loss: 3094.6362 - val_loss: 2512.1348
# Epoch 21/100
# 3/3 [==============================] - 0s 23ms/step - loss: 3086.5161 - val_loss: 2505.1228
# Epoch 22/100
# 3/3 [==============================] - 0s 22ms/step - loss: 3077.7908 - val_loss: 2497.6328
# Epoch 23/100
# 3/3 [==============================] - 0s 22ms/step - loss: 3068.4780 - val_loss: 2489.5859
# Epoch 24/100
# 3/3 [==============================] - 0s 22ms/step - loss: 3058.7925 - val_loss: 2480.9551
# Epoch 25/100
# 3/3 [==============================] - 0s 20ms/step - loss: 3047.9741 - val_loss: 2471.8093
# Epoch 26/100
# 3/3 [==============================] - 0s 20ms/step - loss: 3036.7058 - val_loss: 2462.0186
# Epoch 27/100
# 3/3 [==============================] - 0s 20ms/step - loss: 3024.9644 - val_loss: 2451.5632
# Epoch 28/100
# 3/3 [==============================] - 0s 20ms/step - loss: 3012.1550 - val_loss: 2440.5159
# Epoch 29/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2998.4407 - val_loss: 2428.8201
# Epoch 30/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2983.4661 - val_loss: 2416.4734
# Epoch 31/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2968.5332 - val_loss: 2403.2119
# Epoch 32/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2951.7139 - val_loss: 2389.2305
# Epoch 33/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2934.7522 - val_loss: 2374.3735
# Epoch 34/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2916.5046 - val_loss: 2358.7117
# Epoch 35/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2897.2329 - val_loss: 2342.1843
# Epoch 36/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2876.0295 - val_loss: 2324.7876
# Epoch 37/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2854.6548 - val_loss: 2306.3196
# Epoch 38/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2831.7949 - val_loss: 2287.0583
# Epoch 39/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2807.3706 - val_loss: 2267.0859
# Epoch 40/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2782.2095 - val_loss: 2245.9856
# Epoch 41/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2755.2214 - val_loss: 2223.7710
# Epoch 42/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2728.4915 - val_loss: 2200.3079
# Epoch 43/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2699.2102 - val_loss: 2176.0210
# Epoch 44/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2669.7769 - val_loss: 2150.8628
# Epoch 45/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2638.8062 - val_loss: 2124.9971
# Epoch 46/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2605.3977 - val_loss: 2098.4902
# Epoch 47/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2570.9287 - val_loss: 2071.1064
# Epoch 48/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2538.5825 - val_loss: 2042.4059
# Epoch 49/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2502.0083 - val_loss: 2013.1472
# Epoch 50/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2465.3931 - val_loss: 1983.0671
# Epoch 51/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2427.0796 - val_loss: 1952.3113
# Epoch 52/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2387.0852 - val_loss: 1920.9573
# Epoch 53/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2347.4341 - val_loss: 1888.5787
# Epoch 54/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2307.2041 - val_loss: 1855.2996
# Epoch 55/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2263.1479 - val_loss: 1821.7571
# Epoch 56/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2222.9060 - val_loss: 1787.3278
# Epoch 57/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2177.9780 - val_loss: 1753.0065
# Epoch 58/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2134.7107 - val_loss: 1718.3597
# Epoch 59/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2088.4177 - val_loss: 1683.9205
# Epoch 60/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2045.2113 - val_loss: 1649.0414
# Epoch 61/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1996.7588 - val_loss: 1614.5653
# Epoch 62/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1954.1973 - val_loss: 1579.4949
# Epoch 63/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1906.3317 - val_loss: 1544.8699
# Epoch 64/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1860.8516 - val_loss: 1510.1565
# Epoch 65/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1815.9338 - val_loss: 1475.4717
# Epoch 66/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1767.9924 - val_loss: 1441.5087
# Epoch 67/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1722.8132 - val_loss: 1407.9309
# Epoch 68/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1674.7747 - val_loss: 1375.4534
# Epoch 69/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1631.5217 - val_loss: 1343.1613
# Epoch 70/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1586.4919 - val_loss: 1311.5479
# Epoch 71/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1544.3105 - val_loss: 1280.8577
# Epoch 72/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1498.5437 - val_loss: 1252.0573
# Epoch 73/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1459.1603 - val_loss: 1224.2390
# Epoch 74/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1419.1187 - val_loss: 1198.0168
# Epoch 75/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1379.1794 - val_loss: 1173.7219
# Epoch 76/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1343.4434 - val_loss: 1150.6018
# Epoch 77/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1306.1965 - val_loss: 1129.0256
# Epoch 78/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1272.1245 - val_loss: 1108.6688
# Epoch 79/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1241.2405 - val_loss: 1089.3369
# Epoch 80/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1208.9268 - val_loss: 1071.9851
# Epoch 81/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1178.7532 - val_loss: 1056.2189
# Epoch 82/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1151.8467 - val_loss: 1041.5911
# Epoch 83/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1124.4497 - val_loss: 1028.4331
# Epoch 84/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1100.0785 - val_loss: 1016.7213
# Epoch 85/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1076.1312 - val_loss: 1006.6558
# Epoch 86/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1055.4171 - val_loss: 997.9458
# Epoch 87/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1034.7549 - val_loss: 990.6736
# Epoch 88/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1018.7633 - val_loss: 984.6084
# Epoch 89/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1000.4811 - val_loss: 980.0087
# Epoch 90/100
# 3/3 [==============================] - 0s 20ms/step - loss: 985.3439 - val_loss: 976.4482
# Epoch 91/100
# 3/3 [==============================] - 0s 21ms/step - loss: 969.6437 - val_loss: 973.8851
# Epoch 92/100
# 3/3 [==============================] - 0s 19ms/step - loss: 959.8929 - val_loss: 972.1183
# Epoch 93/100
# 3/3 [==============================] - 0s 21ms/step - loss: 949.4154 - val_loss: 971.2843
# Epoch 94/100
# 3/3 [==============================] - 0s 20ms/step - loss: 939.0426 - val_loss: 971.2619
# Epoch 95/100
# 3/3 [==============================] - 0s 16ms/step - loss: 931.7897 - val_loss: 971.9457
# Epoch 96/100
# 3/3 [==============================] - 0s 16ms/step - loss: 921.1193 - val_loss: 973.1383
# Epoch 97/100
# 3/3 [==============================] - 0s 16ms/step - loss: 915.9889 - val_loss: 974.9835
# Epoch 98/100
# 3/3 [==============================] - 0s 16ms/step - loss: 909.5640 - val_loss: 977.2189
# Epoch 99/100
# 3/3 [==============================] - 0s 16ms/step - loss: 905.0032 - val_loss: 979.8531
# 1/1 [==============================] - 0s 59ms/step
# Epoch 1/100
# 3/3 [==============================] - 1s 83ms/step - loss: 3082.4954 - val_loss: 2991.7537
# Epoch 2/100
# 3/3 [==============================] - 0s 20ms/step - loss: 3078.8235 - val_loss: 2988.4329
# Epoch 3/100
# 3/3 [==============================] - 0s 20ms/step - loss: 3075.6572 - val_loss: 2985.4814
# Epoch 4/100
# 3/3 [==============================] - 0s 20ms/step - loss: 3072.6016 - val_loss: 2982.2935
# Epoch 5/100
# 3/3 [==============================] - 0s 20ms/step - loss: 3069.2183 - val_loss: 2978.7031
# Epoch 6/100
# 3/3 [==============================] - 0s 20ms/step - loss: 3065.4448 - val_loss: 2974.7456
# Epoch 7/100
# 3/3 [==============================] - 0s 20ms/step - loss: 3061.4089 - val_loss: 2970.4731
# Epoch 8/100
# 3/3 [==============================] - 0s 20ms/step - loss: 3057.0571 - val_loss: 2965.7593
# Epoch 9/100
# 3/3 [==============================] - 0s 20ms/step - loss: 3052.2622 - val_loss: 2960.6633
# Epoch 10/100
# 3/3 [==============================] - 0s 20ms/step - loss: 3046.9307 - val_loss: 2955.3240
# Epoch 11/100
# 3/3 [==============================] - 0s 21ms/step - loss: 3041.4109 - val_loss: 2949.6738
# Epoch 12/100
# 3/3 [==============================] - 0s 21ms/step - loss: 3035.6987 - val_loss: 2943.6519
# Epoch 13/100
# 3/3 [==============================] - 0s 22ms/step - loss: 3029.4463 - val_loss: 2937.1106
# Epoch 14/100
# 3/3 [==============================] - 0s 22ms/step - loss: 3022.7356 - val_loss: 2930.0991
# Epoch 15/100
# 3/3 [==============================] - 0s 22ms/step - loss: 3015.8640 - val_loss: 2922.4426
# Epoch 16/100
# 3/3 [==============================] - 0s 23ms/step - loss: 3007.8464 - val_loss: 2914.2446
# Epoch 17/100
# 3/3 [==============================] - 0s 23ms/step - loss: 2999.2942 - val_loss: 2905.5295
# Epoch 18/100
# 3/3 [==============================] - 0s 24ms/step - loss: 2990.3208 - val_loss: 2896.2271
# Epoch 19/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2980.6013 - val_loss: 2886.2908
# Epoch 20/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2970.2961 - val_loss: 2875.6724
# Epoch 21/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2959.4290 - val_loss: 2864.3677
# Epoch 22/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2948.1389 - val_loss: 2852.3142
# Epoch 23/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2935.5308 - val_loss: 2839.5503
# Epoch 24/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2922.4985 - val_loss: 2825.8643
# Epoch 25/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2908.2627 - val_loss: 2811.2664
# Epoch 26/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2893.5859 - val_loss: 2795.6978
# Epoch 27/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2877.5325 - val_loss: 2779.2986
# Epoch 28/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2861.1753 - val_loss: 2761.8503
# Epoch 29/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2842.6660 - val_loss: 2743.5425
# Epoch 30/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2824.1597 - val_loss: 2723.9927
# Epoch 31/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2803.9744 - val_loss: 2703.3650
# Epoch 32/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2783.1997 - val_loss: 2681.5203
# Epoch 33/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2761.2034 - val_loss: 2658.5527
# Epoch 34/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2737.3101 - val_loss: 2634.7417
# Epoch 35/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2713.4170 - val_loss: 2609.6602
# Epoch 36/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2687.3970 - val_loss: 2583.3403
# Epoch 37/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2661.6550 - val_loss: 2555.6594
# Epoch 38/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2633.3042 - val_loss: 2527.0120
# Epoch 39/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2604.9207 - val_loss: 2497.1941
# Epoch 40/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2572.5215 - val_loss: 2466.5747
# Epoch 41/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2542.5249 - val_loss: 2434.1130
# Epoch 42/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2509.7793 - val_loss: 2400.3933
# Epoch 43/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2476.1716 - val_loss: 2365.5000
# Epoch 44/100
# 3/3 [==============================] - 0s 27ms/step - loss: 2439.8784 - val_loss: 2329.8572
# Epoch 45/100
# 3/3 [==============================] - 0s 23ms/step - loss: 2404.4077 - val_loss: 2292.7371
# Epoch 46/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2368.3152 - val_loss: 2254.3135
# Epoch 47/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2330.9661 - val_loss: 2215.0332
# Epoch 48/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2290.4651 - val_loss: 2175.1814
# Epoch 49/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2250.1812 - val_loss: 2134.2642
# Epoch 50/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2209.5396 - val_loss: 2092.1716
# Epoch 51/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2168.7634 - val_loss: 2048.8679
# Epoch 52/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2126.1262 - val_loss: 2004.9397
# Epoch 53/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2080.1724 - val_loss: 1960.8073
# Epoch 54/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2037.4957 - val_loss: 1915.5436
# Epoch 55/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1991.8252 - val_loss: 1869.8625
# Epoch 56/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1947.0312 - val_loss: 1823.1693
# Epoch 57/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1903.0925 - val_loss: 1775.7815
# Epoch 58/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1856.6609 - val_loss: 1728.7281
# Epoch 59/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1809.2777 - val_loss: 1682.2750
# Epoch 60/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1764.2701 - val_loss: 1635.6736
# Epoch 61/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1719.5463 - val_loss: 1589.1379
# Epoch 62/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1674.1110 - val_loss: 1542.8079
# Epoch 63/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1630.0756 - val_loss: 1496.9475
# Epoch 64/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1585.7887 - val_loss: 1451.9685
# Epoch 65/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1543.9144 - val_loss: 1407.2982
# Epoch 66/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1500.4269 - val_loss: 1363.6700
# Epoch 67/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1456.5200 - val_loss: 1321.3066
# Epoch 68/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1419.9763 - val_loss: 1278.6926
# Epoch 69/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1379.0881 - val_loss: 1238.2133
# Epoch 70/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1344.2164 - val_loss: 1199.1434
# Epoch 71/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1307.7571 - val_loss: 1162.6619
# Epoch 72/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1274.8496 - val_loss: 1128.2247
# Epoch 73/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1243.2563 - val_loss: 1095.6714
# Epoch 74/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1213.8049 - val_loss: 1064.8962
# Epoch 75/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1186.9777 - val_loss: 1035.9641
# Epoch 76/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1162.5798 - val_loss: 1008.8908
# Epoch 77/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1136.6947 - val_loss: 984.1333
# Epoch 78/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1116.8088 - val_loss: 960.4668
# Epoch 79/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1097.1354 - val_loss: 938.5215
# Epoch 80/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1080.4840 - val_loss: 918.2598
# Epoch 81/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1061.3998 - val_loss: 900.7172
# Epoch 82/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1047.6060 - val_loss: 884.0955
# Epoch 83/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1032.8307 - val_loss: 869.0381
# Epoch 84/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1021.4704 - val_loss: 855.0584
# Epoch 85/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1012.6166 - val_loss: 842.2227
# Epoch 86/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1003.1216 - val_loss: 831.0447
# Epoch 87/100
# 3/3 [==============================] - 0s 20ms/step - loss: 993.5430 - val_loss: 821.6622
# Epoch 88/100
# 3/3 [==============================] - 0s 21ms/step - loss: 987.6642 - val_loss: 812.8692
# Epoch 89/100
# 3/3 [==============================] - 0s 19ms/step - loss: 982.5715 - val_loss: 805.2902
# Epoch 90/100
# 3/3 [==============================] - 0s 20ms/step - loss: 976.3674 - val_loss: 799.2467
# Epoch 91/100
# 3/3 [==============================] - 0s 20ms/step - loss: 971.8544 - val_loss: 793.7850
# Epoch 92/100
# 3/3 [==============================] - 0s 20ms/step - loss: 968.8623 - val_loss: 788.4697
# Epoch 93/100
# 3/3 [==============================] - 0s 19ms/step - loss: 965.4387 - val_loss: 783.9528
# Epoch 94/100
# 3/3 [==============================] - 0s 20ms/step - loss: 961.8226 - val_loss: 780.2503
# Epoch 95/100
# 3/3 [==============================] - 0s 20ms/step - loss: 960.0486 - val_loss: 776.6995
# Epoch 96/100
# 3/3 [==============================] - 0s 19ms/step - loss: 957.5446 - val_loss: 773.6349
# Epoch 97/100
# 3/3 [==============================] - 0s 19ms/step - loss: 956.2030 - val_loss: 770.7684
# Epoch 98/100
# 3/3 [==============================] - 0s 19ms/step - loss: 954.4955 - val_loss: 768.4229
# Epoch 99/100
# 3/3 [==============================] - 0s 19ms/step - loss: 953.4750 - val_loss: 766.3422
# Epoch 100/100
# 3/3 [==============================] - 0s 20ms/step - loss: 952.3461 - val_loss: 764.8007
# 1/1 [==============================] - 0s 64ms/step
# Epoch 1/100
# 3/3 [==============================] - 1s 88ms/step - loss: 3189.5947 - val_loss: 2568.5559
# Epoch 2/100
# 3/3 [==============================] - 0s 20ms/step - loss: 3182.3489 - val_loss: 2561.9753
# Epoch 3/100
# 3/3 [==============================] - 0s 20ms/step - loss: 3176.0024 - val_loss: 2555.4817
# Epoch 4/100
# 3/3 [==============================] - 0s 20ms/step - loss: 3169.3040 - val_loss: 2549.2200
# Epoch 5/100
# 3/3 [==============================] - 0s 20ms/step - loss: 3162.8867 - val_loss: 2543.0168
# Epoch 6/100
# 3/3 [==============================] - 0s 20ms/step - loss: 3156.7935 - val_loss: 2536.9160
# Epoch 7/100
# 3/3 [==============================] - 0s 21ms/step - loss: 3150.6479 - val_loss: 2530.9253
# Epoch 8/100
# 3/3 [==============================] - 0s 21ms/step - loss: 3144.2104 - val_loss: 2524.8330
# Epoch 9/100
# 3/3 [==============================] - 0s 21ms/step - loss: 3138.1770 - val_loss: 2518.4780
# Epoch 10/100
# 3/3 [==============================] - 0s 21ms/step - loss: 3131.2886 - val_loss: 2511.8423
# Epoch 11/100
# 3/3 [==============================] - 0s 21ms/step - loss: 3124.5425 - val_loss: 2504.8525
# Epoch 12/100
# 3/3 [==============================] - 0s 20ms/step - loss: 3117.1372 - val_loss: 2497.5801
# Epoch 13/100
# 3/3 [==============================] - 0s 21ms/step - loss: 3109.6340 - val_loss: 2489.8809
# Epoch 14/100
# 3/3 [==============================] - 0s 21ms/step - loss: 3101.5100 - val_loss: 2481.8538
# Epoch 15/100
# 3/3 [==============================] - 0s 23ms/step - loss: 3092.7671 - val_loss: 2473.2935
# Epoch 16/100
# 3/3 [==============================] - 0s 21ms/step - loss: 3083.6033 - val_loss: 2463.9136
# Epoch 17/100
# 3/3 [==============================] - 0s 20ms/step - loss: 3073.9607 - val_loss: 2453.8997
# Epoch 18/100
# 3/3 [==============================] - 0s 20ms/step - loss: 3063.2847 - val_loss: 2443.2864
# Epoch 19/100
# 3/3 [==============================] - 0s 19ms/step - loss: 3051.6492 - val_loss: 2431.9968
# Epoch 20/100
# 3/3 [==============================] - 0s 21ms/step - loss: 3039.5212 - val_loss: 2419.9272
# Epoch 21/100
# 3/3 [==============================] - 0s 21ms/step - loss: 3026.4541 - val_loss: 2407.0127
# Epoch 22/100
# 3/3 [==============================] - 0s 21ms/step - loss: 3012.7446 - val_loss: 2393.1572
# Epoch 23/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2998.2515 - val_loss: 2378.4380
# Epoch 24/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2981.5510 - val_loss: 2362.9543
# Epoch 25/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2965.0259 - val_loss: 2346.2690
# Epoch 26/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2947.2468 - val_loss: 2328.5059
# Epoch 27/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2927.9819 - val_loss: 2309.8037
# Epoch 28/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2907.9084 - val_loss: 2290.0176
# Epoch 29/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2886.2402 - val_loss: 2269.2581
# Epoch 30/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2864.3057 - val_loss: 2247.3545
# Epoch 31/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2839.9878 - val_loss: 2224.5122
# Epoch 32/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2814.9417 - val_loss: 2200.4539
# Epoch 33/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2788.9458 - val_loss: 2175.0349
# Epoch 34/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2760.8833 - val_loss: 2148.4355
# Epoch 35/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2733.5283 - val_loss: 2120.4226
# Epoch 36/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2701.0786 - val_loss: 2091.8201
# Epoch 37/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2671.5671 - val_loss: 2061.7493
# Epoch 38/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2636.8884 - val_loss: 2031.0706
# Epoch 39/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2603.1260 - val_loss: 1999.0527
# Epoch 40/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2567.4534 - val_loss: 1965.8503
# Epoch 41/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2531.5488 - val_loss: 1931.3414
# Epoch 42/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2493.9529 - val_loss: 1896.1504
# Epoch 43/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2454.7742 - val_loss: 1860.5963
# Epoch 44/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2415.1135 - val_loss: 1824.4011
# Epoch 45/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2374.1226 - val_loss: 1787.5023
# Epoch 46/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2331.8215 - val_loss: 1749.9153
# Epoch 47/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2289.6223 - val_loss: 1711.3350
# Epoch 48/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2246.4409 - val_loss: 1671.9524
# Epoch 49/100
# 3/3 [==============================] - 0s 23ms/step - loss: 2201.0054 - val_loss: 1632.1699
# Epoch 50/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2155.8774 - val_loss: 1591.9370
# Epoch 51/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2109.3711 - val_loss: 1551.4817
# Epoch 52/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2061.9526 - val_loss: 1510.9873
# Epoch 53/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2016.1589 - val_loss: 1470.4314
# Epoch 54/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1969.0533 - val_loss: 1430.4668
# Epoch 55/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1921.0164 - val_loss: 1390.8933
# Epoch 56/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1873.3746 - val_loss: 1351.5454
# Epoch 57/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1826.5729 - val_loss: 1312.3979
# Epoch 58/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1777.4867 - val_loss: 1273.9197
# Epoch 59/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1731.2527 - val_loss: 1235.7355
# Epoch 60/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1683.6072 - val_loss: 1198.6315
# Epoch 61/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1637.5261 - val_loss: 1162.5247
# Epoch 62/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1593.1909 - val_loss: 1127.4917
# Epoch 63/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1548.3943 - val_loss: 1094.1943
# Epoch 64/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1505.0527 - val_loss: 1062.5834
# Epoch 65/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1462.2258 - val_loss: 1032.7668
# Epoch 66/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1419.7242 - val_loss: 1004.6956
# Epoch 67/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1379.1699 - val_loss: 978.1784
# Epoch 68/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1343.9044 - val_loss: 952.9070
# Epoch 69/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1305.4127 - val_loss: 929.8525
# Epoch 70/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1271.3533 - val_loss: 908.5871
# Epoch 71/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1239.4386 - val_loss: 889.3283
# Epoch 72/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1207.9373 - val_loss: 872.3174
# Epoch 73/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1175.8093 - val_loss: 857.6808
# Epoch 74/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1148.0615 - val_loss: 844.8275
# Epoch 75/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1125.3169 - val_loss: 833.6742
# Epoch 76/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1102.0322 - val_loss: 824.8163
# Epoch 77/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1079.5479 - val_loss: 818.0515
# Epoch 78/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1060.3644 - val_loss: 812.8955
# Epoch 79/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1043.2505 - val_loss: 809.1959
# Epoch 80/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1026.8110 - val_loss: 806.8458
# Epoch 81/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1017.4142 - val_loss: 805.7081
# Epoch 82/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1003.8932 - val_loss: 805.7427
# Epoch 83/100
# 3/3 [==============================] - 0s 16ms/step - loss: 991.5013 - val_loss: 806.6649
# Epoch 84/100
# 3/3 [==============================] - 0s 16ms/step - loss: 982.1537 - val_loss: 808.3729
# Epoch 85/100
# 3/3 [==============================] - 0s 16ms/step - loss: 974.8829 - val_loss: 810.8367
# Epoch 86/100
# 3/3 [==============================] - 0s 17ms/step - loss: 967.5877 - val_loss: 813.8281
# 1/1 [==============================] - 0s 60ms/step

# %%
# Calculate the average scores over all folds
avg_mse = np.mean(mse_scores)
avg_rmse = np.mean(rmse_scores)
avg_mae = np.mean(mae_scores)
avg_r2 = np.mean(r2_scores)

# Print the results
print(f"Average Mean Squared Error: {avg_mse:.2f}%")
print(f"Average Root Mean Squared Error: {avg_rmse:.2f}%")
print(f"Average Mean Absolute Error: {avg_mae:.2f}%")
print(f"Average R-squared: {avg_r2:.2f}%")
# Out:
# Average Mean Squared Error: 962.45%
# Average Root Mean Squared Error: 31.90%
# Average Mean Absolute Error: 27.10%
# Average R-squared: -14.08%

# %%
# Find the most optimal production volume to minimize manufacturing cost
min_production_volume = supply_data['Production volumes'].min()
max_production_volume = 1000
step_size = 100

cheapest_cost = float('inf')
best_production_volume = None

for production_volume in range(min_production_volume, max_production_volume + 1, step_size):
    normalized_production_volume = scaler.transform(np.array([[production_volume]]))
    predicted_cost = model.predict(normalized_production_volume)

    if predicted_cost[0][0] < cheapest_cost:
        cheapest_cost = predicted_cost[0][0]
        best_production_volume = production_volume

print('Most optimal production volume to minimize manufacturing cost:', best_production_volume)
print('The cheapest manufacturing cost:', cheapest_cost)
# Out:
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# Most optimal production volume to minimize manufacturing cost: 104
# The cheapest manufacturing cost: 22.030077
